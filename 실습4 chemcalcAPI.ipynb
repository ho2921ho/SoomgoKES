# %% [markdown]
# # Retrieving information for a molecular formula

# %%
import urllib.request,urllib.parse
import json

ccurl = 'https://www.chemcalc.org/chemcalc/mf'

# Define a molecular formula string
mf = 'C100H100'

# Define the parameters and send them to Chemcalc
params = {
    'mf': mf,
    'isotopomers': 'jcamp,xy'
}
response = urllib.request.urlopen(ccurl, urllib.parse.urlencode(params).encode('utf-8'))

# Read the output and convert it from JSON into a Python dictionary
jsondata = response.read()
data = json.loads(jsondata.decode('utf-8'))

print (data)
# Out:
# {'xy': '1298.783, 0\r\n1300.783, 92.45794\r\n1301.786, 100\r\n1301.789, 1.06339\r\n1302.789, 53.53786\r\n1302.792, 1.15013\r\n1302.795, 0.00605\r\n1303.793, 18.91566\r\n1303.795, 0.61576\r\n1303.798, 0.00655\r\n1304.796, 4.96123\r\n1304.799, 0.21756\r\n1304.802, 0.00351\r\n1305.799, 1.03026\r\n1305.802, 0.05706\r\n1305.805, 0.00124\r\n1306.803, 0.17643\r\n1306.806, 0.01185\r\n1307.806, 0.02562\r\n1307.809, 0.00203\r\n1308.809, 0.00322\r\n1310.809, 0\r\n', 'nominalMass': 1300, 'options': {'typedResult': False, 'referenceVersion': '2013', 'mf': 'C100H100', 'isotopomers': 'jcamp,xy', 'threshold': 1e-05, 'numberLines': 20, 'resolution': 0.001}, 'em': 1300.7825032071, 'parts': [{'unsaturation': 51, 'em': 1300.7825032071, 'mf': 'C100H100', 'mw': 1301.867665, 'ea': [{'number': 100, 'percentage': 92.257733, 'element': 'C'}, {'number': 100, 'percentage': 7.742267, 'element': 'H'}], 'msem': 1300.7825032071}], 'mf': 'C100H100', 'mw': 1301.867665, 'jcamp': '##TITLE= C100H100 - resolution: 0.001\r\n##JCAMP-DX= 5.00\r\n##DATA TYPE= MASS SPECTRUM\r\n##DATA CLASS= PEAK TABLE\r\n##ORIGIN= Generated spectrum based on ChemCalc www.chemcalc.org\r\n##SPECTROMETER/DATA SYSTEM= Based on ChemCalc isotopic distribution calculator\r\n##XUNITS= M/Z\r\n##YUNITS= RELATIVE ABUNDANCE\r\n##NPOINTS= 22\r\n##MAXY= 100\r\n##MINY= 0\r\n##$Unsaturation=51.0\r\n##$Molecular weight=1301.867665\r\n##$Resolution=0.001\r\n##$Threshold=1.0E-5\r\n##$Monoisotopic mass=1300.7825032071\r\n##PEAK TABLE= (XY..XY)\r\n1298.783, 0\r\n1300.783, 92.45794\r\n1301.786, 100\r\n1301.789, 1.06339\r\n1302.789, 53.53786\r\n1302.792, 1.15013\r\n1302.795, 0.00605\r\n1303.793, 18.91566\r\n1303.795, 0.61576\r\n1303.798, 0.00655\r\n1304.796, 4.96123\r\n1304.799, 0.21756\r\n1304.802, 0.00351\r\n1305.799, 1.03026\r\n1305.802, 0.05706\r\n1305.805, 0.00124\r\n1306.803, 0.17643\r\n1306.806, 0.01185\r\n1307.806, 0.02562\r\n1307.809, 0.00203\r\n1308.809, 0.00322\r\n1310.809, 0\r\n##END=\r\n'}

# %% [markdown]
# # Find possible molecular formula for a specific monoisotopic mass

# %%
#!/usr/bin/python

import urllib
import json
import requests

chemcalcURL = 'https://www.chemcalc.org/chemcalc/em'
# Define a molecular formula string
mfRange = 'C0-100H0-100N0-10O0-10'
# target mass
mass = 300

# Define the parameters and send them to Chemcalc

options = {'mfRange': mfRange,
           'monoisotopicMass': mass,
          }

data =  requests.get(chemcalcURL, options).json()

# %%
import pandas as pd

# %%
df = pd.DataFrame(data['results'])
df
# Out:
#              em         mf  unsat     error        ppm       info
# 0    300.000000        C25     26  0.000000     0.0000        C25
# 1    299.999165     C9N8O5     14 -0.000835    -2.7829     N8O5C9
# 2    300.001850  C13H4N2O7     13  0.001850     6.1682  N2O7C13H4
# 3    299.997828   C8H4N4O9      9 -0.002172    -7.2410   N4O9C8H4
# 4    300.003188    C14N6O3     18  0.003188    10.6262    N6O3C14
# ..          ...        ...    ...       ...        ...        ...
# 162  300.288912  C16H36N4O      1  0.288912   962.1128  N4OC16H36
# 163  300.300145   C15H36N6      1  0.300145   999.4840   N6C15H36
# 164  300.302831   C19H40O2      0  0.302831  1008.4171   O2C19H40
# 165  300.314064  C18H40N2O      0  0.314064  1045.7849  N2OC18H40
# 166  300.325297   C17H40N4      0  0.325297  1083.1499   N4C17H40
#
# [167 rows x 6 columns]

# %%
df.to_csv('data/chemcalc.csv', index = False)

# %% [markdown]
# # Alternative code to find possible molecular formula for a specific monoisotopic mass proposed by Guilherme Lopes Batista.

# %%
def mf_finder(mz):

    chemcalcURL = 'https://www.chemcalc.org/chemcalc/em'
    options = {'mfRange': 'C0-100H0-202N0-10O0-10F0-3Cl0-3Br0-1(+)',
               'numberOfResultsOnly': False,
               'typedResult': False,
               'useUnsaturation': False,
               'minUnsaturation': 0,
               'maxUnsaturation': 50,
               'jcampBaseURL': 'http://www.chemcalc.org/service/jcamp/',
               'monoisotopicMass': mz,
               'jcampLink': True,
               # The 'jcamplink' returns a link to a file containing isotopic
               # distribution of retrieved molecular structure.
               'integerUnsaturation': False,
               # Ions/Radicals can have non-integer unsaturation
               'referenceVersion': '2013',
               'massRange': 0.5
#              'minMass': -0.5,
#              'maxMass': 0.5,
              }
    return requests.get(chemcalcURL, options).json()

# %%
mf_finder(300)
# Out:
# {'charge': 1,
#  'bruteForceIteration': 20436416,
#  'realIteration': 102111,
#  'options': {'minMass': 299.5,
#   'mfRange': 'C0-100H0-202N0-10O0-10F0-3Cl0-3Br0-1(+)',
#   'numberOfResultsOnly': False,
#   'typedResult': False,
#   'minUnsaturation': 0,
#   'maxUnsaturation': 50,
#   'useUnsaturation': False,
#   'jcampBaseURL': 'http://www.chemcalc.org/service/jcamp/',
#   'monoisotopicMass': 300,
#   'jcampLink': True,
#   'integerUnsaturation': False,
#   'maxMass': 300.5,
#   'referenceVersion': '2013',
#   'massRange': 0.5},
#  'numberResults': 18026,
#  'results': [{'em': 300.0000314263,
#    'mf': 'C10H10Cl2F2NO3(+1)',
#    'unsat': 4.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2F2NO3C10H10&resolution=0.001',
#    'error': 3.14263e-05,
#    'ppm': 0.1048,
#    'info': 'Cl2F2NO3C10H10(+1)'},
#   {'em': 299.9999592259,
#    'mf': 'C11H2N5O6(+1)',
#    'unsat': 13.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N5O6C11H2&resolution=0.001',
#    'error': -4.07741e-05,
#    'ppm': -0.1359,
#    'info': 'N5O6C11H2(+1)'},
#   {'em': 299.9999469778,
#    'mf': 'CH18BrCl2FN5O2(+1)',
#    'unsat': -6.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrCl2FN5O2CH18&resolution=0.001',
#    'error': -5.30222e-05,
#    'ppm': -0.1767,
#    'info': 'BrCl2FN5O2CH18(+1)'},
#   {'em': 300.0000833095,
#    'mf': 'CH15Cl3N4O7(+1)',
#    'unsat': -5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl3N4O7CH15&resolution=0.001',
#    'error': 8.33095e-05,
#    'ppm': 0.2777,
#    'info': 'Cl3N4O7CH15(+1)'},
#   {'em': 300.0001102692,
#    'mf': 'C3H7BrF2N10(+1)',
#    'unsat': 4,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrF2N10C3H7&resolution=0.001',
#    'error': 0.0001102692,
#    'ppm': 0.3676,
#    'info': 'BrF2N10C3H7(+1)'},
#   {'em': 300.0001155254,
#    'mf': 'C4H13BrF2N3O5(+1)',
#    'unsat': -1.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrF2N3O5C4H13&resolution=0.001',
#    'error': 0.0001155254,
#    'ppm': 0.3851,
#    'info': 'BrF2N3O5C4H13(+1)'},
#   {'em': 300.0001270567,
#    'mf': 'H132F3NO6(+1)',
#    'unsat': -66,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F3NO6H132&resolution=0.001',
#    'error': 0.0001270567,
#    'ppm': 0.4235,
#    'info': 'F3NO6H132(+1)'},
#   {'em': 300.0001467683,
#    'mf': 'C6H19BrCl2N2O2(+1)',
#    'unsat': -3,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrCl2N2O2C6H19&resolution=0.001',
#    'error': 0.0001467683,
#    'ppm': 0.4892,
#    'info': 'BrCl2N2O2C6H19(+1)'},
#   {'em': 300.0001582996,
#    'mf': 'C2H138Cl2FO3(+1)',
#    'unsat': -67.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2FO3C2H138&resolution=0.001',
#    'error': 0.0001582996,
#    'ppm': 0.5277000000000001,
#    'info': 'Cl2FO3C2H138(+1)'},
#   {'em': 299.9998316359,
#    'mf': 'C5H9Cl2F3N4O3(+1)',
#    'unsat': 1,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2F3N4O3C5H9&resolution=0.001',
#    'error': -0.0001683641,
#    'ppm': -0.5612,
#    'info': 'Cl2F3N4O3C5H9(+1)'},
#   {'em': 299.9997594354,
#    'mf': 'C6HFN8O6(+1)',
#    'unsat': 10,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FN8O6C6H&resolution=0.001',
#    'error': -0.0002405646,
#    'ppm': -0.8019,
#    'info': 'FN8O6C6H(+1)'},
#   {'em': 300.0002466009,
#    'mf': 'C3H4ClFN9O5(+1)',
#    'unsat': 5.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFN9O5C3H4&resolution=0.001',
#    'error': 0.0002466009,
#    'ppm': 0.8220000000000001,
#    'info': 'ClFN9O5C3H4(+1)'},
#   {'em': 300.0002518571,
#    'mf': 'C4H10ClFN2O10(+1)',
#    'unsat': 0,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFN2O10C4H10&resolution=0.001',
#    'error': 0.0002518571,
#    'ppm': 0.8394999999999999,
#    'info': 'ClFN2O10C4H10(+1)'},
#   {'em': 300.0003100597,
#    'mf': 'C8H8BrFN7(+1)',
#    'unsat': 7.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrFN7C8H8&resolution=0.001',
#    'error': 0.0003100597,
#    'ppm': 1.0334999999999999,
#    'info': 'BrFN7C8H8(+1)'},
#   {'em': 300.0003153159,
#    'mf': 'C9H14BrFO5(+1)',
#    'unsat': 2,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrFO5C9H14&resolution=0.001',
#    'error': 0.0003153159,
#    'ppm': 1.0511,
#    'info': 'BrFO5C9H14(+1)'},
#   {'em': 300.0003188014,
#    'mf': 'C2H12Cl3F3N5O2(+1)',
#    'unsat': -3.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl3F3N5O2C2H12&resolution=0.001',
#    'error': 0.0003188014,
#    'ppm': 1.0627,
#    'info': 'Cl3F3N5O2C2H12(+1)'},
#   {'em': 300.000321591,
#    'mf': 'C4H127F2N5O(+1)',
#    'unsat': -57,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2N5OC4H127&resolution=0.001',
#    'error': 0.000321591,
#    'ppm': 1.072,
#    'info': 'F2N5OC4H127(+1)'},
#   {'em': 299.9996596028,
#    'mf': 'C9H16BrClNO3(+1)',
#    'unsat': 1.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrClNO3C9H16&resolution=0.001',
#    'error': -0.0003403972,
#    'ppm': -1.1346999999999998,
#    'info': 'BrClNO3C9H16(+1)'},
#   {'em': 300.0003945082,
#    'mf': 'C17F2N3O(+1)',
#    'unsat': 18.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2N3OC17&resolution=0.001',
#    'error': 0.0003945082,
#    'ppm': 1.315,
#    'info': 'F2N3OC17(+1)'},
#   {'em': 299.999596144,
#    'mf': 'C4H12Cl2N3O8(+1)',
#    'unsat': -0.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2N3O8C4H12&resolution=0.001',
#    'error': -0.000403856,
#    'ppm': -1.3461999999999998,
#    'info': 'Cl2N3O8C4H12(+1)'},
#   {'em': 299.9995908878,
#    'mf': 'C3H6Cl2N10O3(+1)',
#    'unsat': 5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2N10O3C3H6&resolution=0.001',
#    'error': -0.0004091122,
#    'ppm': -1.3637,
#    'info': 'Cl2N10O3C3H6(+1)'},
#   {'em': 300.0004369329,
#    'mf': 'H136BrN6(+1)',
#    'unsat': -64.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrN6H136&resolution=0.001',
#    'error': 0.0004369329,
#    'ppm': 1.4564,
#    'info': 'BrN6H136(+1)'},
#   {'em': 300.0004463914,
#    'mf': 'C8H5ClN6O5(+1)',
#    'unsat': 9,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClN6O5C8H5&resolution=0.001',
#    'error': 0.0004463914,
#    'ppm': 1.488,
#    'info': 'ClN6O5C8H5(+1)'},
#   {'em': 299.9995442608,
#    'mf': 'C13H7ClF2O4(+1)',
#    'unsat': 9,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF2O4C13H7&resolution=0.001',
#    'error': -0.0004557392,
#    'ppm': -1.5191,
#    'info': 'ClF2O4C13H7(+1)'},
#   {'em': 299.9995320127,
#    'mf': 'C3H23BrCl3F3(+1)',
#    'unsat': -11,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrCl3F3C3H23&resolution=0.001',
#    'error': -0.0004679873,
#    'ppm': -1.56,
#    'info': 'BrCl3F3C3H23(+1)'},
#   {'em': 299.9995025865,
#    'mf': 'C2H140Cl3NO(+1)',
#    'unsat': -68,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl3NOC2H140&resolution=0.001',
#    'error': -0.0004974135,
#    'ppm': -1.6580000000000001,
#    'info': 'Cl3NOC2H140(+1)'},
#   {'em': 300.0005098502,
#    'mf': 'C13H9BrN4(+1)',
#    'unsat': 11,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrN4C13H9&resolution=0.001',
#    'error': 0.0005098502,
#    'ppm': 1.6995,
#    'info': 'BrN4C13H9(+1)'},
#   {'em': 300.0005185919,
#    'mf': 'C7H13Cl3F2N2O2(+1)',
#    'unsat': 0,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl3F2N2O2C7H13&resolution=0.001',
#    'error': 0.0005185919,
#    'ppm': 1.7286000000000001,
#    'info': 'Cl3F2N2O2C7H13(+1)'},
#   {'em': 300.0005213815,
#    'mf': 'C9H128FN2O(+1)',
#    'unsat': -53.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FN2OC9H128&resolution=0.001',
#    'error': 0.0005213815,
#    'ppm': 1.7379,
#    'info': 'FN2OC9H128(+1)'},
#   {'em': 299.9994713436,
#    'mf': 'H134ClF2N2O4(+1)',
#    'unsat': -66.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF2N2O4H134&resolution=0.001',
#    'error': -0.0005286564,
#    'ppm': -1.7622,
#    'info': 'ClF2N2O4H134(+1)'},
#   {'em': 299.9994598123,
#    'mf': 'C4H15BrClFN4O3(+1)',
#    'unsat': -2,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrClFN4O3C4H15&resolution=0.001',
#    'error': -0.0005401877,
#    'ppm': -1.8006,
#    'info': 'BrClFN4O3C4H15(+1)'},
#   {'em': 299.9994514201,
#    'mf': 'C25(+1)',
#    'unsat': 26,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/C25&resolution=0.001',
#    'error': -0.0005485799,
#    'ppm': -1.8286,
#    'info': 'C25(+1)'},
#   {'em': 300.0005942987,
#    'mf': 'C22HFO(+1)',
#    'unsat': 22,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FOC22H&resolution=0.001',
#    'error': 0.0005942987,
#    'ppm': 1.981,
#    'info': 'FOC22H(+1)'},
#   {'em': 300.0006026909,
#    'mf': 'CH16BrClF2N4O4(+1)',
#    'unsat': -6,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrClF2N4O4CH16&resolution=0.001',
#    'error': 0.0006026909,
#    'ppm': 2.0090000000000003,
#    'info': 'BrClF2N4O4CH16(+1)'},
#   {'em': 299.9993785028,
#    'mf': 'C12H127N2(+1)',
#    'unsat': -49.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N2C12H127&resolution=0.001',
#    'error': -0.0006214972,
#    'ppm': -2.0717,
#    'info': 'N2C12H127(+1)'},
#   {'em': 299.9993757132,
#    'mf': 'C10H12Cl3FN2O(+1)',
#    'unsat': 4,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl3FN2OC10H12&resolution=0.001',
#    'error': -0.0006242868,
#    'ppm': -2.081,
#    'info': 'Cl3FN2OC10H12(+1)'},
#   {'em': 300.0006339338,
#    'mf': 'C3H22BrCl3N3O(+1)',
#    'unsat': -7.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrCl3N3OC3H22&resolution=0.001',
#    'error': 0.0006339338,
#    'ppm': 2.1131,
#    'info': 'BrCl3N3OC3H22(+1)'},
#   {'em': 299.9993444703,
#    'mf': 'C8H6ClF3N3O4(+1)',
#    'unsat': 5.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF3N3O4C8H6&resolution=0.001',
#    'error': -0.0006555297,
#    'ppm': -2.1851000000000003,
#    'info': 'ClF3N3O4C8H6(+1)'},
#   {'em': 300.000677681,
#    'mf': 'C2H139BrF3(+1)',
#    'unsat': -68.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrF3C2H139&resolution=0.001',
#    'error': 0.000677681,
#    'ppm': 2.2589,
#    'info': 'BrF3C2H139(+1)'},
#   {'em': 300.0006818833,
#    'mf': 'C9H2ClF3N7(+1)',
#    'unsat': 10.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF3N7C9H2&resolution=0.001',
#    'error': 0.0006818833,
#    'ppm': 2.2729,
#    'info': 'ClF3N7C9H2(+1)'},
#   {'em': 300.0006871395,
#    'mf': 'C10H8ClF3O5(+1)',
#    'unsat': 5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF3O5C10H8&resolution=0.001',
#    'error': 0.0006871395,
#    'ppm': 2.2904999999999998,
#    'info': 'ClF3O5C10H8(+1)'},
#   {'em': 299.9992912647,
#    'mf': 'CH20BrCl3N6(+1)',
#    'unsat': -7,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrCl3N6CH20&resolution=0.001',
#    'error': -0.0007087353,
#    'ppm': -2.3625,
#    'info': 'BrCl3N6CH20(+1)'},
#   {'em': 300.0007337664,
#    'mf': 'H7Cl2FN10O4(+1)',
#    'unsat': 1,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2FN10O4H7&resolution=0.001',
#    'error': 0.0007337664,
#    'ppm': 2.4459,
#    'info': 'Cl2FN10O4H7(+1)'},
#   {'em': 299.999265278,
#    'mf': 'H20BrClF2O8(+1)',
#    'unsat': -11,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrClF2O8H20&resolution=0.001',
#    'error': -0.000734722,
#    'ppm': -2.4491,
#    'info': 'BrClF2O8H20(+1)'},
#   {'em': 300.0007390226,
#    'mf': 'CH13Cl2FN3O9(+1)',
#    'unsat': -4.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2FN3O9CH13&resolution=0.001',
#    'error': 0.0007390226,
#    'ppm': 2.4634,
#    'info': 'Cl2FN3O9CH13(+1)'},
#   {'em': 300.0008024814,
#    'mf': 'C6H17BrClFNO4(+1)',
#    'unsat': -2.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrClFNO4C6H17&resolution=0.001',
#    'error': 0.0008024814,
#    'ppm': 2.6749,
#    'info': 'BrClFNO4C6H17(+1)'},
#   {'em': 300.0008087565,
#    'mf': 'CH130ClF2N6(+1)',
#    'unsat': -61.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF2N6CH130&resolution=0.001',
#    'error': 0.0008087565,
#    'ppm': 2.6958,
#    'info': 'ClF2N6CH130(+1)'},
#   {'em': 299.9991787123,
#    'mf': 'C7H126FN5(+1)',
#    'unsat': -53,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FN5C7H126&resolution=0.001',
#    'error': -0.0008212877,
#    'ppm': -2.7376,
#    'info': 'FN5C7H126(+1)'},
#   {'em': 299.9991759227,
#    'mf': 'C5H11Cl3F2N5O(+1)',
#    'unsat': 0.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl3F2N5OC5H11&resolution=0.001',
#    'error': -0.0008240773,
#    'ppm': -2.7469,
#    'info': 'Cl3F2N5OC5H11(+1)'},
#   {'em': 299.9991724373,
#    'mf': 'C12H13BrO4(+1)',
#    'unsat': 6,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrO4C12H13&resolution=0.001',
#    'error': -0.0008275627,
#    'ppm': -2.7584999999999997,
#    'info': 'BrO4C12H13(+1)'},
#   {'em': 300.0008816737,
#    'mf': 'C14H3ClF2N4(+1)',
#    'unsat': 14,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF2N4C14H3&resolution=0.001',
#    'error': 0.0008816737,
#    'ppm': 2.9389,
#    'info': 'ClF2N4C14H3(+1)'},
#   {'em': 299.9991089785,
#    'mf': 'C7H9ClN2O9(+1)',
#    'unsat': 4,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClN2O9C7H9&resolution=0.001',
#    'error': -0.0008910215,
#    'ppm': -2.9701,
#    'info': 'ClN2O9C7H9(+1)'},
#   {'em': 299.9991037223,
#    'mf': 'C6H3ClN9O4(+1)',
#    'unsat': 9.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClN9O4C6H3&resolution=0.001',
#    'error': -0.0008962777,
#    'ppm': -2.9876,
#    'info': 'ClN9O4C6H3(+1)'},
#   {'em': 300.000902314,
#    'mf': 'C3H2F2N8O7(+1)',
#    'unsat': 6,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2N8O7C3H2&resolution=0.001',
#    'error': 0.000902314,
#    'ppm': 3.0077,
#    'info': 'F2N8O7C3H2(+1)'},
#   {'em': 300.0009335569,
#    'mf': 'C5H8Cl2N7O4(+1)',
#    'unsat': 4.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2N7O4C5H8&resolution=0.001',
#    'error': 0.0009335569,
#    'ppm': 3.1118,
#    'info': 'Cl2N7O4C5H8(+1)'},
#   {'em': 300.0009388131,
#    'mf': 'C6H14Cl2O9(+1)',
#    'unsat': -1,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2O9C6H14&resolution=0.001',
#    'error': 0.0009388131,
#    'ppm': 3.1294,
#    'info': 'Cl2O9C6H14(+1)'},
#   {'em': 299.9990154209,
#    'mf': 'C5H137Cl2O2(+1)',
#    'unsat': -63.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2O2C5H137&resolution=0.001',
#    'error': -0.0009845791,
#    'ppm': -3.2819,
#    'info': 'Cl2O2C5H137(+1)'},
#   {'em': 300.001008547,
#    'mf': 'C6H131ClFN3(+1)',
#    'unsat': -58,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFN3C6H131&resolution=0.001',
#    'error': 0.001008547,
#    'ppm': 3.3618,
#    'info': 'ClFN3C6H131(+1)'},
#   {'em': 299.9989841781,
#    'mf': 'C3H131F2NO5(+1)',
#    'unsat': -62,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2NO5C3H131&resolution=0.001',
#    'error': -0.0010158219,
#    'ppm': -3.3861,
#    'info': 'F2NO5C3H131(+1)'},
#   {'em': 299.9989813885,
#    'mf': 'CH16Cl3F3NO6(+1)',
#    'unsat': -8.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl3F3NO6CH16&resolution=0.001',
#    'error': -0.0010186115,
#    'ppm': -3.3954,
#    'info': 'Cl3F3NO6CH16(+1)'},
#   {'em': 299.9989789218,
#    'mf': 'C2H125F2N8(+1)',
#    'unsat': -56.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2N8C2H125&resolution=0.001',
#    'error': -0.0010210782,
#    'ppm': -3.4036,
#    'info': 'F2N8C2H125(+1)'},
#   {'em': 299.9989761322,
#    'mf': 'H10Cl3F3N8O(+1)',
#    'unsat': -3,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl3F3N8OH10&resolution=0.001',
#    'error': -0.0010238678,
#    'ppm': -3.4129,
#    'info': 'Cl3F3N8OH10(+1)'},
#   {'em': 299.9989726468,
#    'mf': 'C7H12BrFN3O4(+1)',
#    'unsat': 2.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrFN3O4C7H12&resolution=0.001',
#    'error': -0.0010273532,
#    'ppm': -3.4245,
#    'info': 'BrFN3O4C7H12(+1)'},
#   {'em': 300.0010814642,
#    'mf': 'C19H4ClFN(+1)',
#    'unsat': 17.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFNC19H4&resolution=0.001',
#    'error': 0.0010814642,
#    'ppm': 3.6049,
#    'info': 'ClFNC19H4(+1)'},
#   {'em': 299.998909188,
#    'mf': 'C2H8ClFN5O9(+1)',
#    'unsat': 0.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFN5O9C2H8&resolution=0.001',
#    'error': -0.001090812,
#    'ppm': -3.6361,
#    'info': 'ClFN5O9C2H8(+1)'},
#   {'em': 300.0011021045,
#    'mf': 'C8H3FN5O7(+1)',
#    'unsat': 9.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FN5O7C8H3&resolution=0.001',
#    'error': 0.0011021045,
#    'ppm': 3.6737,
#    'info': 'FN5O7C8H3(+1)'},
#   {'em': 299.9988885477,
#    'mf': 'C13H9Cl2FNO2(+1)',
#    'unsat': 8.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2FNO2C13H9&resolution=0.001',
#    'error': -0.0011114523,
#    'ppm': -3.7049,
#    'info': 'Cl2FNO2C13H9(+1)'},
#   {'em': 299.9988573048,
#    'mf': 'C11H3F3N2O5(+1)',
#    'unsat': 10,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F3N2O5C11H3&resolution=0.001',
#    'error': -0.0011426952,
#    'ppm': -3.8089999999999997,
#    'info': 'F3N2O5C11H3(+1)'},
#   {'em': 300.001174305,
#    'mf': 'C7H11Cl2F3NO4(+1)',
#    'unsat': 0.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2F3NO4C7H11&resolution=0.001',
#    'error': 0.001174305,
#    'ppm': 3.9143,
#    'info': 'Cl2F3NO4C7H11(+1)'},
#   {'em': 299.9988156304,
#    'mf': 'H136Cl2FN3O2(+1)',
#    'unsat': -67,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2FN3O2H136&resolution=0.001',
#    'error': -0.0011843696,
#    'ppm': -3.9478999999999997,
#    'info': 'Cl2FN3O2H136(+1)'},
#   {'em': 299.9988040992,
#    'mf': 'C4H17BrCl2N5O(+1)',
#    'unsat': -2.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrCl2N5OC4H17&resolution=0.001',
#    'error': -0.0011959008,
#    'ppm': -3.9863999999999997,
#    'info': 'BrCl2N5OC4H17(+1)'},
#   {'em': 300.0012083375,
#    'mf': 'C11H132Cl(+1)',
#    'unsat': -54.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClC11H132&resolution=0.001',
#    'error': 0.0012083375,
#    'ppm': 4.0278,
#    'info': 'ClC11H132(+1)'},
#   {'em': 299.9987728563,
#    'mf': 'C2H11BrF2N6O4(+1)',
#    'unsat': -1,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrF2N6O4C2H11&resolution=0.001',
#    'error': -0.0012271437,
#    'ppm': -4.0905000000000005,
#    'info': 'BrF2N6O4C2H11(+1)'},
#   {'em': 300.0012289778,
#    'mf': 'H131N4O7(+1)',
#    'unsat': -62.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N4O7H131&resolution=0.001',
#    'error': 0.0012289778,
#    'ppm': 4.0966,
#    'info': 'N4O7H131(+1)'},
#   {'em': 300.0012531478,
#    'mf': 'H8BrF3N10O(+1)',
#    'unsat': 0,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrF3N10OH8&resolution=0.001',
#    'error': 0.0012531478,
#    'ppm': 4.1771,
#    'info': 'BrF3N10OH8(+1)'},
#   {'em': 300.001258404,
#    'mf': 'CH14BrF3N3O6(+1)',
#    'unsat': -5.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrF3N3O6CH14&resolution=0.001',
#    'error': 0.001258404,
#    'ppm': 4.1947,
#    'info': 'BrF3N3O6CH14(+1)'},
#   {'em': 300.0012896469,
#    'mf': 'C3H20BrCl2FN2O3(+1)',
#    'unsat': -7,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrCl2FN2O3C3H20&resolution=0.001',
#    'error': 0.0012896469,
#    'ppm': 4.2988,
#    'info': 'BrCl2FN2O3C3H20(+1)'},
#   {'em': 300.001301895,
#    'mf': 'C13H4N2O7(+1)',
#    'unsat': 13,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N2O7C13H4&resolution=0.001',
#    'error': 0.001301895,
#    'ppm': 4.3396,
#    'info': 'N2O7C13H4(+1)'},
#   {'em': 299.9986887572,
#    'mf': 'C8H8Cl2F2N4O2(+1)',
#    'unsat': 5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2F2N4O2C8H8&resolution=0.001',
#    'error': -0.0013112428,
#    'ppm': -4.3708,
#    'info': 'Cl2F2N4O2C8H8(+1)'},
#   {'em': 299.998621813,
#    'mf': 'C10H6NO10(+1)',
#    'unsat': 8.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/NO10C10H6&resolution=0.001',
#    'error': -0.001378187,
#    'ppm': -4.594,
#    'info': 'NO10C10H6(+1)'},
#   {'em': 299.9986165568,
#    'mf': 'C9N8O5(+1)',
#    'unsat': 14,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N8O5C9&resolution=0.001',
#    'error': -0.0013834432,
#    'ppm': -4.6114999999999995,
#    'info': 'N8O5C9(+1)'},
#   {'em': 300.0013894796,
#    'mf': 'H5ClF2N9O6(+1)',
#    'unsat': 1.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF2N9O6H5&resolution=0.001',
#    'error': 0.0013894796,
#    'ppm': 4.6316,
#    'info': 'ClF2N9O6H5(+1)'},
#   {'em': 299.9986095649,
#    'mf': 'H22BrCl2FNO6(+1)',
#    'unsat': -11.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrCl2FNO6H22&resolution=0.001',
#    'error': -0.0013904351,
#    'ppm': -4.6348,
#    'info': 'BrCl2FNO6H22(+1)'},
#   {'em': 300.0014207224,
#    'mf': 'C2H11Cl3N8O3(+1)',
#    'unsat': 0,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl3N8O3C2H11&resolution=0.001',
#    'error': 0.0014207224,
#    'ppm': 4.7357000000000005,
#    'info': 'Cl3N8O3C2H11(+1)'},
#   {'em': 300.0014259787,
#    'mf': 'C3H17Cl3NO8(+1)',
#    'unsat': -5.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl3NO8C3H17&resolution=0.001',
#    'error': 0.0014259787,
#    'ppm': 4.7532,
#    'info': 'Cl3NO8C3H17(+1)'},
#   {'em': 300.0014529383,
#    'mf': 'C5H9BrF2N7O(+1)',
#    'unsat': 3.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrF2N7OC5H9&resolution=0.001',
#    'error': 0.0014529383,
#    'ppm': 4.843100000000001,
#    'info': 'BrF2N7OC5H9(+1)'},
#   {'em': 300.0014581945,
#    'mf': 'C6H15BrF2O6(+1)',
#    'unsat': -2,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrF2O6C6H15&resolution=0.001',
#    'error': 0.0014581945,
#    'ppm': 4.8606,
#    'info': 'BrF2O6C6H15(+1)'},
#   {'em': 300.0014644696,
#    'mf': 'CH128F3N5O2(+1)',
#    'unsat': -61,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F3N5O2CH128&resolution=0.001',
#    'error': 0.0014644696,
#    'ppm': 4.8815,
#    'info': 'F3N5O2CH128(+1)'},
#   {'em': 299.9984942229,
#    'mf': 'C4H13Cl2F3O7(+1)',
#    'unsat': -4,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2F3O7C4H13&resolution=0.001',
#    'error': -0.0015057771,
#    'ppm': -5.0193,
#    'info': 'Cl2F3O7C4H13(+1)'},
#   {'em': 299.9984889667,
#    'mf': 'C3H7Cl2F3N7O2(+1)',
#    'unsat': 1.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2F3N7O2C3H7&resolution=0.001',
#    'error': -0.0015110333,
#    'ppm': -5.0367999999999995,
#    'info': 'Cl2F3N7O2C3H7(+1)'},
#   {'em': 300.0015373869,
#    'mf': 'C14HF3N3O2(+1)',
#    'unsat': 14.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F3N3O2C14H&resolution=0.001',
#    'error': 0.0015373869,
#    'ppm': 5.1246,
#    'info': 'F3N3O2C14H(+1)'},
#   {'em': 299.9984220225,
#    'mf': 'C5H5FN4O10(+1)',
#    'unsat': 5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FN4O10C5H5&resolution=0.001',
#    'error': -0.0015779775,
#    'ppm': -5.26,
#    'info': 'FN4O10C5H5(+1)'},
#   {'em': 300.00158927,
#    'mf': 'C5H6ClFN6O6(+1)',
#    'unsat': 5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFN6O6C5H6&resolution=0.001',
#    'error': 0.00158927,
#    'ppm': 5.297499999999999,
#    'info': 'ClFN6O6C5H6(+1)'},
#   {'em': 299.9984013822,
#    'mf': 'C16H6ClFO3(+1)',
#    'unsat': 13,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFO3C16H6&resolution=0.001',
#    'error': -0.0015986178,
#    'ppm': -5.328799999999999,
#    'info': 'ClFO3C16H6(+1)'},
#   {'em': 300.0016527288,
#    'mf': 'C10H10BrFN4O(+1)',
#    'unsat': 7,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrFN4OC10H10&resolution=0.001',
#    'error': 0.0016527288,
#    'ppm': 5.5091,
#    'info': 'BrFN4OC10H10(+1)'},
#   {'em': 300.0016614705,
#    'mf': 'C4H14Cl3F3N2O3(+1)',
#    'unsat': -4,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl3F3N2O3C4H14&resolution=0.001',
#    'error': 0.0016614705,
#    'ppm': 5.5382,
#    'info': 'Cl3F3N2O3C4H14(+1)'},
#   {'em': 300.0016642601,
#    'mf': 'C6H129F2N2O2(+1)',
#    'unsat': -57.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2N2O2C6H129&resolution=0.001',
#    'error': 0.0016642601,
#    'ppm': 5.547499999999999,
#    'info': 'F2N2O2C6H129(+1)'},
#   {'em': 299.9983284649,
#    'mf': 'C3H133ClFN2O3(+1)',
#    'unsat': -62.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFN2O3C3H133&resolution=0.001',
#    'error': -0.0016715351,
#    'ppm': -5.5718,
#    'info': 'ClFN2O3C3H133(+1)'},
#   {'em': 299.9983169336,
#    'mf': 'C7H14BrClN4O2(+1)',
#    'unsat': 2,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrClN4O2C7H14&resolution=0.001',
#    'error': -0.0016830664,
#    'ppm': -5.6103000000000005,
#    'info': 'BrClN4O2C7H14(+1)'},
#   {'em': 300.0017371774,
#    'mf': 'C19H2F2O2(+1)',
#    'unsat': 18,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2O2C19H2&resolution=0.001',
#    'error': 0.0017371774,
#    'ppm': 5.7906,
#    'info': 'F2O2C19H2(+1)'},
#   {'em': 299.9982534749,
#    'mf': 'C2H10Cl2N6O7(+1)',
#    'unsat': 0,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2N6O7C2H10&resolution=0.001',
#    'error': -0.0017465251,
#    'ppm': -5.8218,
#    'info': 'Cl2N6O7C2H10(+1)'},
#   {'em': 299.9982328346,
#    'mf': 'C13H11Cl3N2(+1)',
#    'unsat': 8,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl3N2C13H11&resolution=0.001',
#    'error': -0.0017671654,
#    'ppm': -5.8906,
#    'info': 'Cl3N2C13H11(+1)'},
#   {'em': 300.0017768124,
#    'mf': 'H23BrCl3FN3O2(+1)',
#    'unsat': -11.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrCl3FN3O2H23&resolution=0.001',
#    'error': 0.0017768124,
#    'ppm': 5.9227,
#    'info': 'BrCl3FN3O2H23(+1)'},
#   {'em': 299.998222232,
#    'mf': 'H4F2N7O10(+1)',
#    'unsat': 1.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2N7O10H4&resolution=0.001',
#    'error': -0.001777768,
#    'ppm': -5.9259,
#    'info': 'F2N7O10H4(+1)'},
#   {'em': 300.001779602,
#    'mf': 'C2H138BrN3O(+1)',
#    'unsat': -65,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrN3OC2H138&resolution=0.001',
#    'error': 0.001779602,
#    'ppm': 5.932,
#    'info': 'BrN3OC2H138(+1)'},
#   {'em': 300.0017838043,
#    'mf': 'C9HClN10O(+1)',
#    'unsat': 14,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClN10OC9H&resolution=0.001',
#    'error': 0.0017838043,
#    'ppm': 5.946000000000001,
#    'info': 'ClN10OC9H(+1)'},
#   {'em': 300.0017890605,
#    'mf': 'C10H7ClN3O6(+1)',
#    'unsat': 8.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClN3O6C10H7&resolution=0.001',
#    'error': 0.0017890605,
#    'ppm': 5.9635,
#    'info': 'ClN3O6C10H7(+1)'},
#   {'em': 299.9982015917,
#    'mf': 'C11H5ClF2N3O3(+1)',
#    'unsat': 9.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF2N3O3C11H5&resolution=0.001',
#    'error': -0.0017984083,
#    'ppm': -5.994700000000001,
#    'info': 'ClF2N3O3C11H5(+1)'},
#   {'em': 299.9981599173,
#    'mf': 'H138Cl3N4(+1)',
#    'unsat': -67.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl3N4H138&resolution=0.001',
#    'error': -0.0018400827,
#    'ppm': -6.1336,
#    'info': 'Cl3N4H138(+1)'},
#   {'em': 300.0018525193,
#    'mf': 'C15H11BrNO(+1)',
#    'unsat': 10.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrNOC15H11&resolution=0.001',
#    'error': 0.0018525193,
#    'ppm': 6.175,
#    'info': 'BrNOC15H11(+1)'},
#   {'em': 299.9981223994,
#    'mf': 'C3H19BrClFO7(+1)',
#    'unsat': -7,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrClFO7C3H19&resolution=0.001',
#    'error': -0.0018776006,
#    'ppm': -6.2587,
#    'info': 'BrClFO7C3H19(+1)'},
#   {'em': 299.9981171432,
#    'mf': 'C2H13BrClFN7O2(+1)',
#    'unsat': -1.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrClFN7O2C2H13&resolution=0.001',
#    'error': -0.0018828568,
#    'ppm': -6.2762,
#    'info': 'BrClFN7O2C2H13(+1)'},
#   {'em': 300.0019401038,
#    'mf': 'C2H12BrClF2N8(+1)',
#    'unsat': -1,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrClF2N8C2H12&resolution=0.001',
#    'error': 0.0019401038,
#    'ppm': 6.4670000000000005,
#    'info': 'BrClF2N8C2H12(+1)'},
#   {'em': 300.00194536,
#    'mf': 'C3H18BrClF2NO5(+1)',
#    'unsat': -6.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrClF2NO5C3H18&resolution=0.001',
#    'error': 0.00194536,
#    'ppm': 6.484500000000001,
#    'info': 'BrClF2NO5C3H18(+1)'},
#   {'em': 299.9980330441,
#    'mf': 'C8H10Cl3FN5(+1)',
#    'unsat': 4.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl3FN5C8H10&resolution=0.001',
#    'error': -0.0019669559,
#    'ppm': -6.5566,
#    'info': 'Cl3FN5C8H10(+1)'},
#   {'em': 300.0019766029,
#    'mf': 'C5H24BrCl3O2(+1)',
#    'unsat': -8,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrCl3O2C5H24&resolution=0.001',
#    'error': 0.0019766029,
#    'ppm': 6.5886,
#    'info': 'BrCl3O2C5H24(+1)'},
#   {'em': 299.9980018012,
#    'mf': 'C6H4ClF3N6O3(+1)',
#    'unsat': 6,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF3N6O3C6H4&resolution=0.001',
#    'error': -0.0019981988,
#    'ppm': -6.660699999999999,
#    'info': 'ClF3N6O3C6H4(+1)'},
#   {'em': 300.0020245524,
#    'mf': 'C11H4ClF3N4O(+1)',
#    'unsat': 10,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF3N4OC11H4&resolution=0.001',
#    'error': 0.0020245524,
#    'ppm': 6.7485,
#    'info': 'ClF3N4OC11H4(+1)'},
#   {'em': 300.0020451927,
#    'mf': 'H3F3N8O8(+1)',
#    'unsat': 2,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F3N8O8H3&resolution=0.001',
#    'error': 0.0020451927,
#    'ppm': 6.8173,
#    'info': 'F3N8O8H3(+1)'},
#   {'em': 299.9979538518,
#    'mf': 'H24BrCl3N2O4(+1)',
#    'unsat': -12,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrCl3N2O4H24&resolution=0.001',
#    'error': -0.0020461482,
#    'ppm': -6.8205,
#    'info': 'BrCl3N2O4H24(+1)'},
#   {'em': 300.0020764356,
#    'mf': 'C2H9Cl2FN7O5(+1)',
#    'unsat': 0.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2FN7O5C2H9&resolution=0.001',
#    'error': 0.0020764356,
#    'ppm': 6.9214,
#    'info': 'Cl2FN7O5C2H9(+1)'},
#   {'em': 300.0020816918,
#    'mf': 'C3H15Cl2FO10(+1)',
#    'unsat': -5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2FO10C3H15&resolution=0.001',
#    'error': 0.0020816918,
#    'ppm': 6.938899999999999,
#    'info': 'Cl2FO10C3H15(+1)'},
#   {'em': 300.0021398943,
#    'mf': 'C7H13BrClFN5(+1)',
#    'unsat': 2.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrClFN5C7H13&resolution=0.001',
#    'error': 0.0021398943,
#    'ppm': 7.1329,
#    'info': 'BrClFN5C7H13(+1)'},
#   {'em': 300.0021514256,
#    'mf': 'C3H132ClF2N3O(+1)',
#    'unsat': -62,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF2N3OC3H132&resolution=0.001',
#    'error': 0.0021514256,
#    'ppm': 7.171399999999999,
#    'info': 'ClF2N3OC3H132(+1)'},
#   {'em': 299.9978412994,
#    'mf': 'C6H130FNO4(+1)',
#    'unsat': -58,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FNO4C6H130&resolution=0.001',
#    'error': -0.0021587006,
#    'ppm': -7.1957,
#    'info': 'FNO4C6H130(+1)'},
#   {'em': 299.9978385098,
#    'mf': 'C4H15Cl3F2NO5(+1)',
#    'unsat': -4.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl3F2NO5C4H15&resolution=0.001',
#    'error': -0.0021614902,
#    'ppm': -7.204999999999999,
#    'info': 'Cl3F2NO5C4H15(+1)'},
#   {'em': 299.9978332536,
#    'mf': 'C3H9Cl3F2N8(+1)',
#    'unsat': 1,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl3F2N8C3H9&resolution=0.001',
#    'error': -0.0021667464,
#    'ppm': -7.2225,
#    'info': 'Cl3F2N8C3H9(+1)'},
#   {'em': 299.9978297681,
#    'mf': 'C10H11BrN3O3(+1)',
#    'unsat': 6.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrN3O3C10H11&resolution=0.001',
#    'error': -0.0021702319,
#    'ppm': -7.2342,
#    'info': 'BrN3O3C10H11(+1)'},
#   {'em': 300.0022243429,
#    'mf': 'C16H5ClF2NO(+1)',
#    'unsat': 13.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF2NOC16H5&resolution=0.001',
#    'error': 0.0022243429,
#    'ppm': 7.4144,
#    'info': 'ClF2NOC16H5(+1)'},
#   {'em': 299.9977663094,
#    'mf': 'C5H7ClN5O8(+1)',
#    'unsat': 4.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClN5O8C5H7&resolution=0.001',
#    'error': -0.0022336906,
#    'ppm': -7.4456999999999995,
#    'info': 'ClN5O8C5H7(+1)'},
#   {'em': 300.0022449832,
#    'mf': 'C5H4F2N5O8(+1)',
#    'unsat': 5.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2N5O8C5H4&resolution=0.001',
#    'error': 0.0022449832,
#    'ppm': 7.4832,
#    'info': 'F2N5O8C5H4(+1)'},
#   {'em': 299.9977456691,
#    'mf': 'C16H8Cl2NO(+1)',
#    'unsat': 12.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2NOC16H8&resolution=0.001',
#    'error': -0.0022543309,
#    'ppm': -7.5145,
#    'info': 'Cl2NOC16H8(+1)'},
#   {'em': 300.002276226,
#    'mf': 'C7H10Cl2N4O5(+1)',
#    'unsat': 4,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2N4O5C7H10&resolution=0.001',
#    'error': 0.002276226,
#    'ppm': 7.587400000000001,
#    'info': 'Cl2N4O5C7H10(+1)'},
#   {'em': 299.9977144262,
#    'mf': 'C14H2F2N2O4(+1)',
#    'unsat': 14,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2N2O4C14H2&resolution=0.001',
#    'error': -0.0022855738,
#    'ppm': -7.6186,
#    'info': 'F2N2O4C14H2(+1)'},
#   {'em': 299.9977021781,
#    'mf': 'C4H18BrCl2F3N2(+1)',
#    'unsat': -6,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrCl2F3N2C4H18&resolution=0.001',
#    'error': -0.0022978219,
#    'ppm': -7.6595,
#    'info': 'BrCl2F3N2C4H18(+1)'},
#   {'em': 299.9976727518,
#    'mf': 'C3H135Cl2N3O(+1)',
#    'unsat': -63,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2N3OC3H135&resolution=0.001',
#    'error': -0.0023272482,
#    'ppm': -7.7576,
#    'info': 'Cl2N3OC3H135(+1)'},
#   {'em': 300.0023396848,
#    'mf': 'C12H14BrClN2(+1)',
#    'unsat': 6,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrClN2C12H14&resolution=0.001',
#    'error': 0.0023396848,
#    'ppm': 7.798900000000001,
#    'info': 'BrClN2C12H14(+1)'},
#   {'em': 300.0023512161,
#    'mf': 'C8H133ClFO(+1)',
#    'unsat': -58.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFOC8H133&resolution=0.001',
#    'error': 0.0023512161,
#    'ppm': 7.8373,
#    'info': 'ClFOC8H133(+1)'},
#   {'em': 299.9976415089,
#    'mf': 'CH129F2N4O4(+1)',
#    'unsat': -61.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2N4O4CH129&resolution=0.001',
#    'error': -0.0023584911,
#    'ppm': -7.8617,
#    'info': 'F2N4O4CH129(+1)'},
#   {'em': 300.0023603251,
#    'mf': 'CH13BrN6O7(+1)',
#    'unsat': -2,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrN6O7CH13&resolution=0.001',
#    'error': 0.0023603251,
#    'ppm': 7.867699999999999,
#    'info': 'BrN6O7CH13(+1)'},
#   {'em': 299.9976299776,
#    'mf': 'C5H10BrFN6O3(+1)',
#    'unsat': 3,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrFN6O3C5H10&resolution=0.001',
#    'error': -0.0023700224,
#    'ppm': -7.900100000000001,
#    'info': 'BrFN6O3C5H10(+1)'},
#   {'em': 300.0024325255,
#    'mf': 'H21BrCl2F2N2O4(+1)',
#    'unsat': -11,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrCl2F2N2O4H21&resolution=0.001',
#    'error': 0.0024325255,
#    'ppm': 8.1084,
#    'info': 'BrCl2F2N2O4H21(+1)'},
#   {'em': 299.9975665189,
#    'mf': 'H6ClFN8O8(+1)',
#    'unsat': 1,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFN8O8H6&resolution=0.001',
#    'error': -0.0024334811,
#    'ppm': -8.1117,
#    'info': 'ClFN8O8H6(+1)'},
#   {'em': 300.0024447737,
#    'mf': 'C10H5FN2O8(+1)',
#    'unsat': 9,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FN2O8C10H5&resolution=0.001',
#    'error': 0.0024447737,
#    'ppm': 8.1492,
#    'info': 'FN2O8C10H5(+1)'},
#   {'em': 299.9975458786,
#    'mf': 'C11H7Cl2FN4O(+1)',
#    'unsat': 9,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2FN4OC11H7&resolution=0.001',
#    'error': -0.0024541214,
#    'ppm': -8.1805,
#    'info': 'Cl2FN4OC11H7(+1)'},
#   {'em': 299.9975146357,
#    'mf': 'C9HF3N5O4(+1)',
#    'unsat': 10.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F3N5O4C9H&resolution=0.001',
#    'error': -0.0024853643,
#    'ppm': -8.284600000000001,
#    'info': 'F3N5O4C9H(+1)'},
#   {'em': 300.0025117179,
#    'mf': 'C8H7Cl2F3N5(+1)',
#    'unsat': 5.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2F3N5C8H7&resolution=0.001',
#    'error': 0.0025117179,
#    'ppm': 8.3723,
#    'info': 'Cl2F3N5C8H7(+1)'},
#   {'em': 299.9974666862,
#    'mf': 'C3H21BrCl2NO5(+1)',
#    'unsat': -7.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrCl2NO5C3H21&resolution=0.001',
#    'error': -0.0025333138,
#    'ppm': -8.4445,
#    'info': 'BrCl2NO5C3H21(+1)'},
#   {'em': 299.99746143,
#    'mf': 'C2H15BrCl2N8(+1)',
#    'unsat': -2,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrCl2N8C2H15&resolution=0.001',
#    'error': -0.00253857,
#    'ppm': -8.462,
#    'info': 'BrCl2N8C2H15(+1)'},
#   {'em': 299.9974354434,
#    'mf': 'CH15BrF2N2O8(+1)',
#    'unsat': -6,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrF2N2O8CH15&resolution=0.001',
#    'error': -0.0025645566,
#    'ppm': -8.5486,
#    'info': 'BrF2N2O8CH15(+1)'},
#   {'em': 300.0025663907,
#    'mf': 'CH127N8O3(+1)',
#    'unsat': -57.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N8O3CH127&resolution=0.001',
#    'error': 0.0025663907,
#    'ppm': 8.554599999999999,
#    'info': 'N8O3CH127(+1)'},
#   {'em': 300.0025688573,
#    'mf': 'H18Cl3FNO9(+1)',
#    'unsat': -9.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl3FNO9H18&resolution=0.001',
#    'error': 0.0025688573,
#    'ppm': 8.562800000000001,
#    'info': 'Cl3FNO9H18(+1)'},
#   {'em': 299.9974301872,
#    'mf': 'H9BrF2N9O3(+1)',
#    'unsat': -0.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrF2N9O3H9&resolution=0.001',
#    'error': -0.0025698128,
#    'ppm': -8.566099999999999,
#    'info': 'BrF2N9O3H9(+1)'},
#   {'em': 300.0025716469,
#    'mf': 'C2H133NO8(+1)',
#    'unsat': -63,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/NO8C2H133&resolution=0.001',
#    'error': 0.0025716469,
#    'ppm': 8.5721,
#    'info': 'NO8C2H133(+1)'},
#   {'em': 300.0025958169,
#    'mf': 'C2H10BrF3N7O2(+1)',
#    'unsat': -0.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrF3N7O2C2H10&resolution=0.001',
#    'error': 0.0025958169,
#    'ppm': 8.652600000000001,
#    'info': 'BrF3N7O2C2H10(+1)'},
#   {'em': 300.0026010732,
#    'mf': 'C3H16BrF3O7(+1)',
#    'unsat': -6,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrF3O7C3H16&resolution=0.001',
#    'error': 0.0026010732,
#    'ppm': 8.670200000000001,
#    'info': 'BrF3O7C3H16(+1)'},
#   {'em': 300.0026385911,
#    'mf': 'H135Cl2F2N4(+1)',
#    'unsat': -66.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2F2N4H135&resolution=0.001',
#    'error': 0.0026385911,
#    'ppm': 8.7952,
#    'info': 'Cl2F2N4H135(+1)'},
#   {'em': 300.0026393079,
#    'mf': 'C14N6O3(+1)',
#    'unsat': 18,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N6O3C14&resolution=0.001',
#    'error': 0.0026393079,
#    'ppm': 8.797600000000001,
#    'info': 'N6O3C14(+1)'},
#   {'em': 299.9973513443,
#    'mf': 'C7H12Cl2F2O6(+1)',
#    'unsat': 0,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2F2O6C7H12&resolution=0.001',
#    'error': -0.0026486557,
#    'ppm': -8.828899999999999,
#    'info': 'Cl2F2O6C7H12(+1)'},
#   {'em': 299.9973460881,
#    'mf': 'C6H6Cl2F2N7O(+1)',
#    'unsat': 5.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2F2N7OC6H6&resolution=0.001',
#    'error': -0.0026539119,
#    'ppm': -8.8465,
#    'info': 'Cl2F2N7OC6H6(+1)'},
#   {'em': 300.0027115084,
#    'mf': 'C13H8Cl2F2N2(+1)',
#    'unsat': 9,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2F2N2C13H8&resolution=0.001',
#    'error': 0.0027115084,
#    'ppm': 9.0383,
#    'info': 'Cl2F2N2C13H8(+1)'},
#   {'em': 299.9972791439,
#    'mf': 'C8H4N4O9(+1)',
#    'unsat': 9,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N4O9C8H4&resolution=0.001',
#    'error': -0.0027208561,
#    'ppm': -9.069600000000001,
#    'info': 'N4O9C8H4(+1)'},
#   {'em': 300.0027321487,
#    'mf': 'C2H7ClF2N6O7(+1)',
#    'unsat': 1,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF2N6O7C2H7&resolution=0.001',
#    'error': 0.0027321487,
#    'ppm': 9.107099999999999,
#    'info': 'ClF2N6O7C2H7(+1)'},
#   {'em': 299.9972585036,
#    'mf': 'C19H5ClO2(+1)',
#    'unsat': 17,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClO2C19H5&resolution=0.001',
#    'error': -0.0027414964,
#    'ppm': -9.1384,
#    'info': 'ClO2C19H5(+1)'},
#   {'em': 300.0027633916,
#    'mf': 'C4H13Cl3N5O4(+1)',
#    'unsat': -0.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl3N5O4C4H13&resolution=0.001',
#    'error': 0.0027633916,
#    'ppm': 9.2112,
#    'info': 'Cl3N5O4C4H13(+1)'},
#   {'em': 299.9972150126,
#    'mf': 'C7H15BrClF3NO(+1)',
#    'unsat': -1.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrClF3NOC7H15&resolution=0.001',
#    'error': -0.0027849874,
#    'ppm': -9.2834,
#    'info': 'BrClF3NOC7H15(+1)'},
#   {'em': 300.0027956074,
#    'mf': 'C7H11BrF2N4O2(+1)',
#    'unsat': 3,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrF2N4O2C7H11&resolution=0.001',
#    'error': 0.0027956074,
#    'ppm': 9.3186,
#    'info': 'BrF2N4O2C7H11(+1)'},
#   {'em': 300.0028071387,
#    'mf': 'C3H130F3N2O3(+1)',
#    'unsat': -61.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F3N2O3C3H130&resolution=0.001',
#    'error': 0.0028071387,
#    'ppm': 9.357000000000001,
#    'info': 'F3N2O3C3H130(+1)'},
#   {'em': 299.9971855863,
#    'mf': 'C6H132ClN2O2(+1)',
#    'unsat': -58.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClN2O2C6H132&resolution=0.001',
#    'error': -0.0028144137,
#    'ppm': -9.381499999999999,
#    'info': 'ClN2O2C6H132(+1)'},
#   {'em': 300.0028383816,
#    'mf': 'C5H136Cl2FN(+1)',
#    'unsat': -63,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2FNC5H136&resolution=0.001',
#    'error': 0.0028383816,
#    'ppm': 9.4612,
#    'info': 'Cl2FNC5H136(+1)'},
#   {'em': 299.9971515538,
#    'mf': 'C2H11Cl2F3N3O6(+1)',
#    'unsat': -3.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2F3N3O6C2H11&resolution=0.001',
#    'error': -0.0028484462,
#    'ppm': -9.4949,
#    'info': 'Cl2F3N3O6C2H11(+1)'},
#   {'em': 299.9971462976,
#    'mf': 'CH5Cl2F3N10O(+1)',
#    'unsat': 2,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2F3N10OCH5&resolution=0.001',
#    'error': -0.0028537024,
#    'ppm': -9.512400000000001,
#    'info': 'Cl2F3N10OCH5(+1)'},
#   {'em': 300.002880056,
#    'mf': 'C16H3F3O3(+1)',
#    'unsat': 14,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F3O3C16H3&resolution=0.001',
#    'error': 0.002880056,
#    'ppm': 9.6001,
#    'info': 'F3O3C16H3(+1)'},
#   {'em': 299.9970793534,
#    'mf': 'C3H3FN7O9(+1)',
#    'unsat': 5.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FN7O9C3H3&resolution=0.001',
#    'error': -0.0029206466,
#    'ppm': -9.7356,
#    'info': 'FN7O9C3H3(+1)'},
#   {'em': 300.002926683,
#    'mf': 'C6H2ClFN10O2(+1)',
#    'unsat': 10,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFN10O2C6H2&resolution=0.001',
#    'error': 0.002926683,
#    'ppm': 9.7555,
#    'info': 'ClFN10O2C6H2(+1)'},
#   {'em': 300.0029319392,
#    'mf': 'C7H8ClFN3O7(+1)',
#    'unsat': 4.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFN3O7C7H8&resolution=0.001',
#    'error': 0.0029319392,
#    'ppm': 9.773,
#    'info': 'ClFN3O7C7H8(+1)'},
#   {'em': 299.9970587131,
#    'mf': 'C14H4ClFN3O2(+1)',
#    'unsat': 13.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFN3O2C14H4&resolution=0.001',
#    'error': -0.0029412869,
#    'ppm': -9.804400000000001,
#    'info': 'ClFN3O2C14H4(+1)'},
#   {'em': 300.0029953979,
#    'mf': 'C12H12BrFNO2(+1)',
#    'unsat': 6.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrFNO2C12H12&resolution=0.001',
#    'error': 0.0029953979,
#    'ppm': 9.984599999999999,
#    'info': 'BrFNO2C12H12(+1)'},
#   {'em': 299.9969857958,
#    'mf': 'CH131ClFN5O2(+1)',
#    'unsat': -62,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFN5O2CH131&resolution=0.001',
#    'error': -0.0030142042,
#    'ppm': -10.0474,
#    'info': 'ClFN5O2CH131(+1)'},
#   {'em': 299.9969795207,
#    'mf': 'C6H18BrClO6(+1)',
#    'unsat': -3,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrClO6C6H18&resolution=0.001',
#    'error': -0.0030204793,
#    'ppm': -10.0684,
#    'info': 'BrClO6C6H18(+1)'},
#   {'em': 299.9969742645,
#    'mf': 'C5H12BrClN7O(+1)',
#    'unsat': 2.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrClN7OC5H12&resolution=0.001',
#    'error': -0.0030257355,
#    'ppm': -10.085899999999999,
#    'info': 'BrClN7OC5H12(+1)'},
#   {'em': 300.0030882387,
#    'mf': 'H19BrClF3NO6(+1)',
#    'unsat': -10.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrClF3NO6H19&resolution=0.001',
#    'error': 0.0030882387,
#    'ppm': 10.294,
#    'info': 'BrClF3NO6H19(+1)'},
#   {'em': 299.9969108058,
#    'mf': 'H8Cl2N9O6(+1)',
#    'unsat': 0.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2N9O6H8&resolution=0.001',
#    'error': -0.0030891942,
#    'ppm': -10.297400000000001,
#    'info': 'Cl2N9O6H8(+1)'},
#   {'em': 300.0031194816,
#    'mf': 'C2H25BrCl3FO3(+1)',
#    'unsat': -12,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrCl3FO3C2H25&resolution=0.001',
#    'error': 0.0031194816,
#    'ppm': 10.3982,
#    'info': 'BrCl3FO3C2H25(+1)'},
#   {'em': 300.0031222712,
#    'mf': 'C4H140BrO2(+1)',
#    'unsat': -65.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrO2C4H140&resolution=0.001',
#    'error': 0.0031222712,
#    'ppm': 10.4075,
#    'info': 'BrO2C4H140(+1)'},
#   {'em': 300.0031264734,
#    'mf': 'C11H3ClN7O2(+1)',
#    'unsat': 13.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClN7O2C11H3&resolution=0.001',
#    'error': 0.0031264734,
#    'ppm': 10.4215,
#    'info': 'ClN7O2C11H3(+1)'},
#   {'em': 300.0031317297,
#    'mf': 'C12H9ClO7(+1)',
#    'unsat': 8,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClO7C12H9&resolution=0.001',
#    'error': 0.0031317297,
#    'ppm': 10.439,
#    'info': 'ClO7C12H9(+1)'},
#   {'em': 299.9968589226,
#    'mf': 'C9H3ClF2N6O2(+1)',
#    'unsat': 10,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF2N6O2C9H3&resolution=0.001',
#    'error': -0.0031410774,
#    'ppm': -10.4704,
#    'info': 'ClF2N6O2C9H3(+1)'},
#   {'em': 299.9967797302,
#    'mf': 'CH17BrClFN3O6(+1)',
#    'unsat': -6.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrClFN3O6CH17&resolution=0.001',
#    'error': -0.0032202698,
#    'ppm': -10.7343,
#    'info': 'BrClFN3O6CH17(+1)'},
#   {'em': 299.996774474,
#    'mf': 'H11BrClFN10O(+1)',
#    'unsat': -1,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrClFN10OH11&resolution=0.001',
#    'error': -0.003225526,
#    'ppm': -10.7519,
#    'info': 'BrClFN10OH11(+1)'},
#   {'em': 299.9967278471,
#    'mf': 'C10H12BrF3O2(+1)',
#    'unsat': 3,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrF3O2C10H12&resolution=0.001',
#    'error': -0.0032721529,
#    'ppm': -10.9073,
#    'info': 'BrF3O2C10H12(+1)'},
#   {'em': 300.0032827729,
#    'mf': 'C4H14BrClF2N5O(+1)',
#    'unsat': -1.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrClF2N5OC4H14&resolution=0.001',
#    'error': 0.0032827729,
#    'ppm': 10.9425,
#    'info': 'BrClF2N5OC4H14(+1)'},
#   {'em': 300.0032943042,
#    'mf': 'H133ClF3N3O2(+1)',
#    'unsat': -66,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF3N3O2H133&resolution=0.001',
#    'error': 0.0032943042,
#    'ppm': 10.9809,
#    'info': 'ClF3N3O2H133(+1)'},
#   {'em': 299.9966984208,
#    'mf': 'C9H129NO3(+1)',
#    'unsat': -54,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/NO3C9H129&resolution=0.001',
#    'error': -0.0033015792,
#    'ppm': -11.0054,
#    'info': 'NO3C9H129(+1)'},
#   {'em': 299.9966956312,
#    'mf': 'C7H14Cl3FNO4(+1)',
#    'unsat': -0.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl3FNO4C7H14&resolution=0.001',
#    'error': -0.0033043688,
#    'ppm': -11.0147,
#    'info': 'Cl3FNO4C7H14(+1)'},
#   {'em': 299.9966643883,
#    'mf': 'C5H8ClF3N2O7(+1)',
#    'unsat': 1,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF3N2O7C5H8&resolution=0.001',
#    'error': -0.0033356117,
#    'ppm': -11.118799999999998,
#    'info': 'ClF3N2O7C5H8(+1)'},
#   {'em': 299.9966591321,
#    'mf': 'C4H2ClF3N9O2(+1)',
#    'unsat': 6.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF3N9O2C4H2&resolution=0.001',
#    'error': -0.0033408679,
#    'ppm': -11.1364,
#    'info': 'ClF3N9O2C4H2(+1)'},
#   {'em': 300.0033672215,
#    'mf': 'C13H6ClF3NO2(+1)',
#    'unsat': 9.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF3NO2C13H6&resolution=0.001',
#    'error': 0.0033672215,
#    'ppm': 11.223899999999999,
#    'info': 'ClF3NO2C13H6(+1)'},
#   {'em': 300.0033878618,
#    'mf': 'C2H5F3N5O9(+1)',
#    'unsat': 1.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F3N5O9C2H5&resolution=0.001',
#    'error': 0.0033878618,
#    'ppm': 11.2927,
#    'info': 'F3N5O9C2H5(+1)'},
#   {'em': 300.0034191047,
#    'mf': 'C4H11Cl2FN4O6(+1)',
#    'unsat': 0,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2FN4O6C4H11&resolution=0.001',
#    'error': 0.0034191047,
#    'ppm': 11.396899999999999,
#    'info': 'Cl2FN4O6C4H11(+1)'},
#   {'em': 299.9965715476,
#    'mf': 'C17HFN2O3(+1)',
#    'unsat': 18,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FN2O3C17H&resolution=0.001',
#    'error': -0.0034284524,
#    'ppm': -11.4283,
#    'info': 'FN2O3C17H(+1)'},
#   {'em': 299.9965708307,
#    'mf': 'C3H136Cl2F3(+1)',
#    'unsat': -66.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2F3C3H136&resolution=0.001',
#    'error': -0.0034291693,
#    'ppm': -11.4307,
#    'info': 'Cl2F3C3H136(+1)'},
#   {'em': 300.0034825634,
#    'mf': 'C9H15BrClFN2O(+1)',
#    'unsat': 2,
# ...
#    'error': 0.0161637116,
#    'ppm': 53.876099999999994,
#    'info': 'F2NO9C8H8(+1)'},
#   {'em': 299.9838269407,
#    'mf': 'C13H4Cl2N5(+1)',
#    'unsat': 13.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2N5C13H4&resolution=0.001',
#    'error': -0.0161730593,
#    'ppm': -53.9131,
#    'info': 'Cl2N5C13H4(+1)'},
#   {'em': 300.0161854959,
#    'mf': 'C2H145BrClO(+1)',
#    'unsat': -70.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrClOC2H145&resolution=0.001',
#    'error': 0.0161854959,
#    'ppm': 53.9487,
#    'info': 'BrClOC2H145(+1)'},
#   {'em': 300.0161896982,
#    'mf': 'C9H8Cl2N7O(+1)',
#    'unsat': 8.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2N7OC9H8&resolution=0.001',
#    'error': 0.0161896982,
#    'ppm': 53.9627,
#    'info': 'Cl2N7OC9H8(+1)'},
#   {'em': 300.0161949545,
#    'mf': 'C10H14Cl2O6(+1)',
#    'unsat': 3,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2O6C10H14&resolution=0.001',
#    'error': 0.0161949545,
#    'ppm': 53.9803,
#    'info': 'Cl2O6C10H14(+1)'},
#   {'em': 299.9837592796,
#    'mf': 'CH137Cl2O5(+1)',
#    'unsat': -67.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2O5CH137&resolution=0.001',
#    'error': -0.0162407204,
#    'ppm': -54.1387,
#    'info': 'Cl2O5CH137(+1)'},
#   {'em': 299.9837540234,
#    'mf': 'H131Cl2N7(+1)',
#    'unsat': -62,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2N7H131&resolution=0.001',
#    'error': -0.0162459766,
#    'ppm': -54.1562,
#    'info': 'Cl2N7H131(+1)'},
#   {'em': 300.0162737973,
#    'mf': 'C3H11BrN9O3(+1)',
#    'unsat': 2.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrN9O3C3H11&resolution=0.001',
#    'error': 0.0162737973,
#    'ppm': 54.243,
#    'info': 'BrN9O3C3H11(+1)'},
#   {'em': 300.0162790535,
#    'mf': 'C4H17BrN2O8(+1)',
#    'unsat': -3,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrN2O8C4H17&resolution=0.001',
#    'error': 0.0162790535,
#    'ppm': 54.260600000000004,
#    'info': 'BrN2O8C4H17(+1)'},
#   {'em': 299.9837165055,
#    'mf': 'C3H12BrFN3O7(+1)',
#    'unsat': -1.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrFN3O7C3H12&resolution=0.001',
#    'error': -0.0162834945,
#    'ppm': -54.2813,
#    'info': 'BrFN3O7C3H12(+1)'},
#   {'em': 299.9837112492,
#    'mf': 'C2H6BrFN10O2(+1)',
#    'unsat': 4,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrFN10O2C2H6&resolution=0.001',
#    'error': -0.0162887508,
#    'ppm': -54.2988,
#    'info': 'BrFN10O2C2H6(+1)'},
#   {'em': 300.0162905848,
#    'mf': 'H136FO9(+1)',
#    'unsat': -67.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FO9H136&resolution=0.001',
#    'error': 0.0162905848,
#    'ppm': 54.29900000000001,
#    'info': 'FO9H136(+1)'},
#   {'em': 300.0163459977,
#    'mf': 'C2H19BrCl2F2N5(+1)',
#    'unsat': -6.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrCl2F2N5C2H19&resolution=0.001',
#    'error': 0.0163459977,
#    'ppm': 54.4837,
#    'info': 'BrCl2F2N5C2H19(+1)'},
#   {'em': 300.0163582458,
#    'mf': 'C12H3FN5O4(+1)',
#    'unsat': 13.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FN5O4C12H3&resolution=0.001',
#    'error': 0.0163582458,
#    'ppm': 54.5245,
#    'info': 'FN5O4C12H3(+1)'},
#   {'em': 299.9836324064,
#    'mf': 'C9H9Cl2FNO5(+1)',
#    'unsat': 4.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2FNO5C9H9&resolution=0.001',
#    'error': -0.0163675936,
#    'ppm': -54.561600000000006,
#    'info': 'Cl2FNO5C9H9(+1)'},
#   {'em': 299.9836271502,
#    'mf': 'C8H3Cl2FN8(+1)',
#    'unsat': 10,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2FN8C8H3&resolution=0.001',
#    'error': -0.0163728498,
#    'ppm': -54.579100000000004,
#    'info': 'Cl2FN8C8H3(+1)'},
#   {'em': 299.9836229479,
#    'mf': 'CH140BrClFN(+1)',
#    'unsat': -69,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrClFNCH140&resolution=0.001',
#    'error': -0.0163770521,
#    'ppm': -54.593199999999996,
#    'info': 'BrClFNCH140(+1)'},
#   {'em': 299.9836011635,
#    'mf': 'C7H3F3N2O8(+1)',
#    'unsat': 6,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F3N2O8C7H3&resolution=0.001',
#    'error': -0.0163988365,
#    'ppm': -54.665800000000004,
#    'info': 'F3N2O8C7H3(+1)'},
#   {'em': 300.0164304463,
#    'mf': 'C11H11Cl2F3NO(+1)',
#    'unsat': 4.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2F3NOC11H11&resolution=0.001',
#    'error': 0.0164304463,
#    'ppm': 54.7652,
#    'info': 'Cl2F3NOC11H11(+1)'},
#   {'em': 300.0164510866,
#    'mf': 'H10ClF3N5O8(+1)',
#    'unsat': -3.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF3N5O8H10&resolution=0.001',
#    'error': 0.0164510866,
#    'ppm': 54.8339,
#    'info': 'ClF3N5O8H10(+1)'},
#   {'em': 299.9835479578,
#    'mf': 'H17BrCl2N5O4(+1)',
#    'unsat': -6.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrCl2N5O4H17&resolution=0.001',
#    'error': -0.0164520422,
#    'ppm': -54.8431,
#    'info': 'BrCl2N5O4H17(+1)'},
#   {'em': 300.0164823295,
#    'mf': 'C2H16Cl3FN4O5(+1)',
#    'unsat': -5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl3FN4O5C2H16&resolution=0.001',
#    'error': 0.0164823295,
#    'ppm': 54.9381,
#    'info': 'Cl3FN4O5C2H16(+1)'},
#   {'em': 300.0164851191,
#    'mf': 'C4H131N4O4(+1)',
#    'unsat': -58.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N4O4C4H131&resolution=0.001',
#    'error': 0.0164851191,
#    'ppm': 54.9474,
#    'info': 'N4O4C4H131(+1)'},
#   {'em': 299.983507606,
#    'mf': 'C5H131ClF3O(+1)',
#    'unsat': -61.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF3OC5H131&resolution=0.001',
#    'error': -0.016492394,
#    'ppm': -54.9777,
#    'info': 'ClF3OC5H131(+1)'},
#   {'em': 299.9834960747,
#    'mf': 'C9H12BrClF2N2(+1)',
#    'unsat': 3,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrClF2N2C9H12&resolution=0.001',
#    'error': -0.0165039253,
#    'ppm': -55.0161,
#    'info': 'BrClF2N2C9H12(+1)'},
#   {'em': 300.0165145453,
#    'mf': 'C5H14BrF3N3O3(+1)',
#    'unsat': -1.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrF3N3O3C5H14&resolution=0.001',
#    'error': 0.0165145453,
#    'ppm': 55.0455,
#    'info': 'BrF3N3O3C5H14(+1)'},
#   {'em': 300.0165457882,
#    'mf': 'C7H20BrCl2FN2(+1)',
#    'unsat': -3,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrCl2FN2C7H20&resolution=0.001',
#    'error': 0.0165457882,
#    'ppm': 55.1496,
#    'info': 'BrCl2FN2C7H20(+1)'},
#   {'em': 300.0165573195,
#    'mf': 'C3H139Cl2F2O(+1)',
#    'unsat': -67.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2F2OC3H139&resolution=0.001',
#    'error': 0.0165573195,
#    'ppm': 55.188,
#    'info': 'Cl2F2OC3H139(+1)'},
#   {'em': 300.0165580363,
#    'mf': 'C17H4N2O4(+1)',
#    'unsat': 17,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N2O4C17H4&resolution=0.001',
#    'error': 0.0165580363,
#    'ppm': 55.1904,
#    'info': 'N2O4C17H4(+1)'},
#   {'em': 299.9834326159,
#    'mf': 'C4H8Cl2F2N4O5(+1)',
#    'unsat': 1,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2F2N4O5C4H8&resolution=0.001',
#    'error': -0.0165673841,
#    'ppm': -55.2277,
#    'info': 'Cl2F2N4O5C4H8(+1)'},
#   {'em': 299.9833604155,
#    'mf': 'C5N8O8(+1)',
#    'unsat': 10,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N8O8C5&resolution=0.001',
#    'error': -0.0166395845,
#    'ppm': -55.468399999999995,
#    'info': 'N8O8C5(+1)'},
#   {'em': 300.0166456209,
#    'mf': 'C4H5ClF2N9O3(+1)',
#    'unsat': 5.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF2N9O3C4H5&resolution=0.001',
#    'error': 0.0166456209,
#    'ppm': 55.4823,
#    'info': 'ClF2N9O3C4H5(+1)'},
#   {'em': 300.0166508771,
#    'mf': 'C5H11ClF2N2O8(+1)',
#    'unsat': 0,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF2N2O8C5H11&resolution=0.001',
#    'error': 0.0166508771,
#    'ppm': 55.4998,
#    'info': 'ClF2N2O8C5H11(+1)'},
#   {'em': 299.9833397752,
#    'mf': 'C16HClN4O(+1)',
#    'unsat': 18,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClN4OC16H&resolution=0.001',
#    'error': -0.0166602248,
#    'ppm': -55.5372,
#    'info': 'ClN4OC16H(+1)'},
#   {'em': 300.0166768638,
#    'mf': 'C6H11Cl3N8(+1)',
#    'unsat': 4,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl3N8C6H11&resolution=0.001',
#    'error': 0.0166768638,
#    'ppm': 55.5865,
#    'info': 'Cl3N8C6H11(+1)'},
#   {'em': 300.01668212,
#    'mf': 'C7H17Cl3NO5(+1)',
#    'unsat': -1.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl3NO5C7H17&resolution=0.001',
#    'error': 0.01668212,
#    'ppm': 55.604,
#    'info': 'Cl3NO5C7H17(+1)'},
#   {'em': 299.9832962842,
#    'mf': 'C4H11BrClF3N5(+1)',
#    'unsat': -0.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrClF3N5C4H11&resolution=0.001',
#    'error': -0.0167037158,
#    'ppm': -55.6822,
#    'info': 'BrClF3N5C4H11(+1)'},
#   {'em': 300.0167143358,
#    'mf': 'C10H15BrF2O3(+1)',
#    'unsat': 2,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrF2O3C10H15&resolution=0.001',
#    'error': 0.0167143358,
#    'ppm': 55.7113,
#    'info': 'BrF2O3C10H15(+1)'},
#   {'em': 299.9832668579,
#    'mf': 'C3H128ClN6O(+1)',
#    'unsat': -57.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClN6OC3H128&resolution=0.001',
#    'error': -0.0167331421,
#    'ppm': -55.7803,
#    'info': 'ClN6OC3H128(+1)'},
#   {'em': 300.0167609628,
#    'mf': 'H14BrClN10O2(+1)',
#    'unsat': -2,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrClN10O2H14&resolution=0.001',
#    'error': 0.0167609628,
#    'ppm': 55.8668,
#    'info': 'BrClN10O2H14(+1)'},
#   {'em': 299.9832380816,
#    'mf': 'H13Cl2F3O10(+1)',
#    'unsat': -8,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2F3O10H13&resolution=0.001',
#    'error': -0.0167619184,
#    'ppm': -55.8762,
#    'info': 'Cl2F3O10H13(+1)'},
#   {'em': 300.016766219,
#    'mf': 'CH20BrClN3O7(+1)',
#    'unsat': -7.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrClN3O7CH20&resolution=0.001',
#    'error': 0.016766219,
#    'ppm': 55.8843,
#    'info': 'BrClN3O7CH20(+1)'},
#   {'em': 300.0168454114,
#    'mf': 'C9H6ClFN6O3(+1)',
#    'unsat': 9,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFN6O3C9H6&resolution=0.001',
#    'error': 0.0168454114,
#    'ppm': 56.148199999999996,
#    'info': 'ClFN6O3C9H6(+1)'},
#   {'em': 299.9831452409,
#    'mf': 'C12H6ClFO6(+1)',
#    'unsat': 9,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFO6C12H6&resolution=0.001',
#    'error': -0.0168547591,
#    'ppm': -56.1857,
#    'info': 'ClFO6C12H6(+1)'},
#   {'em': 299.9831399847,
#    'mf': 'C11ClFN7O(+1)',
#    'unsat': 14.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFN7OC11&resolution=0.001',
#    'error': -0.0168600153,
#    'ppm': -56.203199999999995,
#    'info': 'ClFN7OC11(+1)'},
#   {'em': 299.9831357824,
#    'mf': 'C4H137BrFO(+1)',
#    'unsat': -64.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrFOC4H137&resolution=0.001',
#    'error': -0.0168642176,
#    'ppm': -56.2172,
#    'info': 'BrFOC4H137(+1)'},
#   {'em': 299.9831329928,
#    'mf': 'C2H22BrCl3F2O2(+1)',
#    'unsat': -11,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrCl3F2O2C2H22&resolution=0.001',
#    'error': -0.0168670072,
#    'ppm': -56.2265,
#    'info': 'BrCl3F2O2C2H22(+1)'},
#   {'em': 300.0169176118,
#    'mf': 'C8H14Cl3F3N2(+1)',
#    'unsat': 0,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl3F3N2C8H14&resolution=0.001',
#    'error': 0.0169176118,
#    'ppm': 56.3889,
#    'info': 'Cl3F3N2C8H14(+1)'},
#   {'em': 299.9830607923,
#    'mf': 'C3H14BrClN4O5(+1)',
#    'unsat': -2,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrClN4O5C3H14&resolution=0.001',
#    'error': -0.0169392077,
#    'ppm': -56.4672,
#    'info': 'BrClN4O5C3H14(+1)'},
#   {'em': 300.0169722846,
#    'mf': 'CH134ClN5O3(+1)',
#    'unsat': -63,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClN5O3CH134&resolution=0.001',
#    'error': 0.0169722846,
#    'ppm': 56.5711,
#    'info': 'ClN5O3CH134(+1)'},
#   {'em': 299.9830089092,
#    'mf': 'C12H9BrF2NO(+1)',
#    'unsat': 7.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrF2NOC12H9&resolution=0.001',
#    'error': -0.0169910908,
#    'ppm': -56.6402,
#    'info': 'BrF2NOC12H9(+1)'},
#   {'em': 300.0170017109,
#    'mf': 'C2H17BrClF3N4O2(+1)',
#    'unsat': -6,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrClF3N4O2C2H17&resolution=0.001',
#    'error': 0.0170017109,
#    'ppm': 56.669200000000004,
#    'info': 'BrClF3N4O2C2H17(+1)'},
#   {'em': 299.9829766933,
#    'mf': 'C9H11Cl3N2O3(+1)',
#    'unsat': 4,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl3N2O3C9H11&resolution=0.001',
#    'error': -0.0170233067,
#    'ppm': -56.7476,
#    'info': 'Cl3N2O3C9H11(+1)'},
#   {'em': 300.017044485,
#    'mf': 'H142Cl3F2N(+1)',
#    'unsat': -72,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl3F2NH142&resolution=0.001',
#    'error': 0.017044485,
#    'ppm': 56.811699999999995,
#    'info': 'Cl3F2NH142(+1)'},
#   {'em': 300.0170452019,
#    'mf': 'C14H7ClN3O3(+1)',
#    'unsat': 12.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClN3O3C14H7&resolution=0.001',
#    'error': 0.0170452019,
#    'ppm': 56.8141,
#    'info': 'ClN3O3C14H7(+1)'},
#   {'em': 299.9829454504,
#    'mf': 'C7H5ClF2N3O6(+1)',
#    'unsat': 5.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF2N3O6C7H5&resolution=0.001',
#    'error': -0.0170545496,
#    'ppm': -56.8517,
#    'info': 'ClF2N3O6C7H5(+1)'},
#   {'em': 300.0170658422,
#    'mf': 'C3H6N7O10(+1)',
#    'unsat': 4.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N7O10C3H6&resolution=0.001',
#    'error': 0.0170658422,
#    'ppm': 56.8829,
#    'info': 'N7O10C3H6(+1)'},
#   {'em': 300.0171327864,
#    'mf': 'CH8Cl2F2N10O2(+1)',
#    'unsat': 1,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2F2N10O2CH8&resolution=0.001',
#    'error': 0.0171327864,
#    'ppm': 57.106,
#    'info': 'Cl2F2N10O2CH8(+1)'},
#   {'em': 300.0171380426,
#    'mf': 'C2H14Cl2F2N3O7(+1)',
#    'unsat': -4.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2F2N3O7C2H14&resolution=0.001',
#    'error': 0.0171380426,
#    'ppm': 57.1235,
#    'info': 'Cl2F2N3O7C2H14(+1)'},
#   {'em': 299.9828091187,
#    'mf': 'C7H8BrF3N4O(+1)',
#    'unsat': 4,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrF3N4OC7H8&resolution=0.001',
#    'error': -0.0171908813,
#    'ppm': -57.3062,
#    'info': 'BrF3N4OC7H8(+1)'},
#   {'em': 300.0172015014,
#    'mf': 'C7H18BrClF2NO2(+1)',
#    'unsat': -2.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrClF2NO2C7H18&resolution=0.001',
#    'error': 0.0172015014,
#    'ppm': 57.3351,
#    'info': 'BrClF2NO2C7H18(+1)'},
#   {'em': 299.9827796924,
#    'mf': 'C6H125N5O2(+1)',
#    'unsat': -53,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N5O2C6H125&resolution=0.001',
#    'error': -0.0172203076,
#    'ppm': -57.4043,
#    'info': 'N5O2C6H125(+1)'},
#   {'em': 299.9827769028,
#    'mf': 'C4H10Cl3FN5O3(+1)',
#    'unsat': 0.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl3FN5O3C4H10&resolution=0.001',
#    'error': -0.0172230972,
#    'ppm': -57.4136,
#    'info': 'Cl3FN5O3C4H10(+1)'},
#   {'em': 299.9827456599,
#    'mf': 'C2H4ClF3N6O6(+1)',
#    'unsat': 2,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF3N6O6C2H4&resolution=0.001',
#    'error': -0.0172543401,
#    'ppm': -57.5178,
#    'info': 'ClF3N6O6C2H4(+1)'},
#   {'em': 300.017301334,
#    'mf': 'C4H3F3N8O5(+1)',
#    'unsat': 6,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F3N8O5C4H3&resolution=0.001',
#    'error': 0.017301334,
#    'ppm': 57.6678,
#    'info': 'F3N8O5C4H3(+1)'},
#   {'em': 300.0173065902,
#    'mf': 'C5H9F3NO10(+1)',
#    'unsat': 0.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F3NO10C5H9&resolution=0.001',
#    'error': 0.0173065902,
#    'ppm': 57.6853,
#    'info': 'F3NO10C5H9(+1)'},
#   {'em': 300.0173325769,
#    'mf': 'C6H9Cl2FN7O2(+1)',
#    'unsat': 4.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2FN7O2C6H9&resolution=0.001',
#    'error': 0.0173325769,
#    'ppm': 57.7719,
#    'info': 'Cl2FN7O2C6H9(+1)'},
#   {'em': 300.0173378331,
#    'mf': 'C7H15Cl2FO7(+1)',
#    'unsat': -1,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2FO7C7H15&resolution=0.001',
#    'error': 0.0173378331,
#    'ppm': 57.7894,
#    'info': 'Cl2FO7C7H15(+1)'},
#   {'em': 299.9825851581,
#    'mf': 'C2H130FNO7(+1)',
#    'unsat': -62,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FNO7C2H130&resolution=0.001',
#    'error': -0.0174148419,
#    'ppm': -58.0528,
#    'info': 'FNO7C2H130(+1)'}]}

# %%
mf_finder(100)
# Out:
# {'charge': 1,
#  'bruteForceIteration': 1209600,
#  'realIteration': 2294,
#  'options': {'minMass': 99.5,
#   'mfRange': 'C0-100H0-202N0-10O0-10F0-3Cl0-3Br0-1(+)',
#   'numberOfResultsOnly': False,
#   'typedResult': False,
#   'minUnsaturation': 0,
#   'maxUnsaturation': 50,
#   'useUnsaturation': False,
#   'jcampBaseURL': 'http://www.chemcalc.org/service/jcamp/',
#   'monoisotopicMass': 100,
#   'jcampLink': True,
#   'integerUnsaturation': False,
#   'maxMass': 100.5,
#   'referenceVersion': '2013',
#   'massRange': 0.5},
#  'numberResults': 307,
#  'results': [{'em': 100.0002392657,
#    'mf': 'H4O6(+1)',
#    'unsat': -1,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O6H4&resolution=0.001',
#    'error': 0.0002392657,
#    'ppm': 2.3927,
#    'info': 'O6H4(+1)'},
#   {'em': 100.0004747576,
#    'mf': 'CHF3NO(+1)',
#    'unsat': 0.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F3ONCH&resolution=0.001',
#    'error': 0.0004747576,
#    'ppm': 4.7476,
#    'info': 'F3ONCH(+1)'},
#   {'em': 99.999331879,
#    'mf': 'C4F2N(+1)',
#    'unsat': 4.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2NC4&resolution=0.001',
#    'error': -0.000668121,
#    'ppm': -6.6813,
#    'info': 'F2NC4(+1)'},
#   {'em': 100.0015766787,
#    'mf': 'CN4O2(+1)',
#    'unsat': 4,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O2N4C&resolution=0.001',
#    'error': 0.0015766787,
#    'ppm': 15.766499999999999,
#    'info': 'O2N4C(+1)'},
#   {'em': 100.0029193478,
#    'mf': 'C3H2NO3(+1)',
#    'unsat': 3.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O3NC3H2&resolution=0.001',
#    'error': 0.0029193478,
#    'ppm': 29.1926,
#    'info': 'O3NC3H2(+1)'},
#   {'em': 99.9966517969,
#    'mf': 'CH2F2O3(+1)',
#    'unsat': 0,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2O3CH2&resolution=0.001',
#    'error': -0.0033482031,
#    'ppm': -33.4832,
#    'info': 'F2O3CH2(+1)'},
#   {'em': 100.0034065133,
#    'mf': 'H5ClN2O2(+1)',
#    'unsat': -1,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClO2N2H5&resolution=0.001',
#    'error': 0.0034065133,
#    'ppm': 34.064,
#    'info': 'ClO2N2H5(+1)'},
#   {'em': 99.9959960838,
#    'mf': 'CH4ClFNO(+1)',
#    'unsat': -0.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFONCH4&resolution=0.001',
#    'error': -0.0040039162,
#    'ppm': -40.0408,
#    'info': 'ClFONCH4(+1)'},
#   {'em': 100.0040622264,
#    'mf': 'H3FNO4(+1)',
#    'unsat': -0.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FO4NH3&resolution=0.001',
#    'error': 0.0040622264,
#    'ppm': 40.6206,
#    'info': 'FO4NH3(+1)'},
#   {'em': 99.9955089183,
#    'mf': 'C4HFO2(+1)',
#    'unsat': 4,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FO2C4H&resolution=0.001',
#    'error': -0.0044910817,
#    'ppm': -44.912800000000004,
#    'info': 'FO2C4H(+1)'},
#   {'em': 99.9948532052,
#    'mf': 'C4H3ClN(+1)',
#    'unsat': 3.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClNC4H3&resolution=0.001',
#    'error': -0.0051467948,
#    'ppm': -51.470600000000005,
#    'info': 'ClNC4H3(+1)'},
#   {'em': 100.0055994298,
#    'mf': 'C6N2(+1)',
#    'unsat': 8,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N2C6&resolution=0.001',
#    'error': 0.0055994298,
#    'ppm': 55.9912,
#    'info': 'N2C6(+1)'},
#   {'em': 99.9943660397,
#    'mf': 'C7O(+1)',
#    'unsat': 8,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/OC7&resolution=0.001',
#    'error': -0.0056339603,
#    'ppm': -56.3428,
#    'info': 'OC7(+1)'},
#   {'em': 100.0067423084,
#    'mf': 'C3HFN2O(+1)',
#    'unsat': 4,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FON2C3H&resolution=0.001',
#    'error': 0.0067423084,
#    'ppm': 67.41850000000001,
#    'info': 'FON2C3H(+1)'},
#   {'em': 100.007229474,
#    'mf': 'H4ClFN3(+1)',
#    'unsat': -0.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFN3H4&resolution=0.001',
#    'error': 0.007229474,
#    'ppm': 72.2895,
#    'info': 'ClFN3H4(+1)'},
#   {'em': 100.0074292644,
#    'mf': 'C5H5Cl(+1)',
#    'unsat': 3,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClC5H5&resolution=0.001',
#    'error': 0.0074292644,
#    'ppm': 74.2871,
#    'info': 'ClC5H5(+1)'},
#   {'em': 99.9921731231,
#    'mf': 'CH5ClO3(+1)',
#    'unsat': -1,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClO3CH5&resolution=0.001',
#    'error': -0.0078268769,
#    'ppm': -78.2749,
#    'info': 'ClO3CH5(+1)'},
#   {'em': 100.0078851871,
#    'mf': 'H2F2N2O2(+1)',
#    'unsat': 0,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2O2N2H2&resolution=0.001',
#    'error': 0.0078851871,
#    'ppm': 78.84570000000001,
#    'info': 'F2O2N2H2(+1)'},
#   {'em': 100.0085721431,
#    'mf': 'C2H6ClFO(+1)',
#    'unsat': -1,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFOC2H6&resolution=0.001',
#    'error': 0.0085721431,
#    'ppm': 85.7141,
#    'info': 'ClFOC2H6(+1)'},
#   {'em': 99.9903432885,
#    'mf': 'C2N2O3(+1)',
#    'unsat': 4,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O3N2C2&resolution=0.001',
#    'error': -0.0096567115,
#    'ppm': -96.5764,
#    'info': 'O3N2C2(+1)'},
#   {'em': 99.9885856543,
#    'mf': 'C2H3ClF2(+1)',
#    'unsat': 0,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF2C2H3&resolution=0.001',
#    'error': -0.0114143457,
#    'ppm': -114.15650000000001,
#    'info': 'ClF2C2H3(+1)'},
#   {'em': 100.0117081477,
#    'mf': 'HF3N3(+1)',
#    'unsat': 0.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F3N3H&resolution=0.001',
#    'error': 0.0117081477,
#    'ppm': 117.06779999999999,
#    'info': 'F3N3H(+1)'},
#   {'em': 99.9882138307,
#    'mf': 'CH9Br(+1)',
#    'unsat': -3,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrCH9&resolution=0.001',
#    'error': -0.0117861693,
#    'ppm': -117.87559999999999,
#    'info': 'BrCH9(+1)'},
#   {'em': 100.0119079382,
#    'mf': 'C5H2F2(+1)',
#    'unsat': 4,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2C5H2&resolution=0.001',
#    'error': 0.0119079382,
#    'ppm': 119.0652,
#    'info': 'F2C5H2(+1)'},
#   {'em': 100.0128100688,
#    'mf': 'N6O(+1)',
#    'unsat': 4,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ON6&resolution=0.001',
#    'error': 0.0128100688,
#    'ppm': 128.0843,
#    'info': 'ON6(+1)'},
#   {'em': 100.0130508169,
#    'mf': 'C2H3F3O(+1)',
#    'unsat': 0,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F3OC2H3&resolution=0.001',
#    'error': 0.0130508169,
#    'ppm': 130.4911,
#    'info': 'F3OC2H3(+1)'},
#   {'em': 100.0141527379,
#    'mf': 'C2H2N3O2(+1)',
#    'unsat': 3.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O2N3C2H2&resolution=0.001',
#    'error': 0.0141527379,
#    'ppm': 141.5074,
#    'info': 'O2N3C2H2(+1)'},
#   {'em': 100.0154954071,
#    'mf': 'C4H4O3(+1)',
#    'unsat': 3,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O3C4H4&resolution=0.001',
#    'error': 0.0154954071,
#    'ppm': 154.93009999999998,
#    'info': 'O3C4H4(+1)'},
#   {'em': 99.9841069805,
#    'mf': 'C2H6Cl2(+1)',
#    'unsat': -1,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2C2H6&resolution=0.001',
#    'error': -0.0158930195,
#    'ppm': -158.9555,
#    'info': 'Cl2C2H6(+1)'},
#   {'em': 99.9840757376,
#    'mf': 'F2NO3(+1)',
#    'unsat': 0.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2O3N&resolution=0.001',
#    'error': -0.0159242624,
#    'ppm': -159.268,
#    'info': 'F2O3N(+1)'},
#   {'em': 100.0159825726,
#    'mf': 'CH7ClNO2(+1)',
#    'unsat': -1.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClO2NCH7&resolution=0.001',
#    'error': 0.0159825726,
#    'ppm': 159.8002,
#    'info': 'ClO2NCH7(+1)'},
#   {'em': 99.9834200245,
#    'mf': 'H2ClFN2O(+1)',
#    'unsat': 0,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFON2H2&resolution=0.001',
#    'error': -0.0165799755,
#    'ppm': -165.8272,
#    'info': 'ClFON2H2(+1)'},
#   {'em': 100.0166382857,
#    'mf': 'CH5FO4(+1)',
#    'unsat': -1,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FO4CH5&resolution=0.001',
#    'error': 0.0166382857,
#    'ppm': 166.3552,
#    'info': 'FO4CH5(+1)'},
#   {'em': 99.9822771459,
#    'mf': 'C3HClN2(+1)',
#    'unsat': 4,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClN2C3H&resolution=0.001',
#    'error': -0.0177228541,
#    'ppm': -177.26,
#    'info': 'ClN2C3H(+1)'},
#   {'em': 100.0179756986,
#    'mf': 'C2HFN4(+1)',
#    'unsat': 4,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FN4C2H&resolution=0.001',
#    'error': 0.0179756986,
#    'ppm': 179.72469999999998,
#    'info': 'FN4C2H(+1)'},
#   {'em': 100.0181754891,
#    'mf': 'C7H2N(+1)',
#    'unsat': 7.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/NC7H2&resolution=0.001',
#    'error': 0.0181754891,
#    'ppm': 181.7219,
#    'info': 'NC7H2(+1)'},
#   {'em': 100.0193183677,
#    'mf': 'C4H3FNO(+1)',
#    'unsat': 3.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FONC4H3&resolution=0.001',
#    'error': 0.0193183677,
#    'ppm': 193.1464,
#    'info': 'FONC4H3(+1)'},
#   {'em': 99.980252777,
#    'mf': 'HFO5(+1)',
#    'unsat': 0,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FO5H&resolution=0.001',
#    'error': -0.019747223,
#    'ppm': -197.5112,
#    'info': 'FO5H(+1)'},
#   {'em': 100.0198055332,
#    'mf': 'CH6ClFN2(+1)',
#    'unsat': -1,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFN2CH6&resolution=0.001',
#    'error': 0.0198055332,
#    'ppm': 198.0161,
#    'info': 'ClFN2CH6(+1)'},
#   {'em': 99.9795970638,
#    'mf': 'H3ClNO3(+1)',
#    'unsat': -0.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClO3NH3&resolution=0.001',
#    'error': -0.0204029362,
#    'ppm': -204.071,
#    'info': 'ClO3NH3(+1)'},
#   {'em': 100.0204612464,
#    'mf': 'CH4F2NO2(+1)',
#    'unsat': -0.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2O2NCH4&resolution=0.001',
#    'error': 0.0204612464,
#    'ppm': 204.57059999999998,
#    'info': 'F2O2NCH4(+1)'},
#   {'em': 99.9791098983,
#    'mf': 'C3O4(+1)',
#    'unsat': 4,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O4C3&resolution=0.001',
#    'error': -0.0208901017,
#    'ppm': -208.94469999999998,
#    'info': 'O4C3(+1)'},
#   {'em': 100.0216353679,
#    'mf': 'H11Cl2F(+1)',
#    'unsat': -6,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2FH11&resolution=0.001',
#    'error': 0.0216353679,
#    'ppm': 216.30689999999998,
#    'info': 'Cl2FH11(+1)'},
#   {'em': 99.976009595,
#    'mf': 'CHClF2N(+1)',
#    'unsat': 0.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF2NCH&resolution=0.001',
#    'error': -0.023990405,
#    'ppm': -239.9616,
#    'info': 'ClF2NCH(+1)'},
#   {'em': 100.0240487152,
#    'mf': 'H6NO5(+1)',
#    'unsat': -1.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O5NH6&resolution=0.001',
#    'error': 0.0240487152,
#    'ppm': 240.4293,
#    'info': 'O5NH6(+1)'},
#   {'em': 100.024284207,
#    'mf': 'CH3F3N2(+1)',
#    'unsat': 0,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F3N2CH3&resolution=0.001',
#    'error': 0.024284207,
#    'ppm': 242.7831,
#    'info': 'F3N2CH3(+1)'},
#   {'em': 99.9756377714,
#    'mf': 'H7BrN(+1)',
#    'unsat': -2.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrNH7&resolution=0.001',
#    'error': -0.0243622286,
#    'ppm': -243.6817,
#    'info': 'BrNH7(+1)'},
#   {'em': 100.0253861281,
#    'mf': 'CH2N5O(+1)',
#    'unsat': 3.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ON5CH2&resolution=0.001',
#    'error': 0.0253861281,
#    'ppm': 253.79690000000002,
#    'info': 'ON5CH2(+1)'},
#   {'em': 100.0261140417,
#    'mf': 'H8ClF3(+1)',
#    'unsat': -5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF3H8&resolution=0.001',
#    'error': 0.0261140417,
#    'ppm': 261.0722,
#    'info': 'ClF3H8(+1)'},
#   {'em': 100.0267287972,
#    'mf': 'C3H4N2O2(+1)',
#    'unsat': 3,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O2N2C3H4&resolution=0.001',
#    'error': 0.0267287972,
#    'ppm': 267.2165,
#    'info': 'O2N2C3H4(+1)'},
#   {'em': 100.0272159627,
#    'mf': 'H7ClN3O(+1)',
#    'unsat': -1.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClON3H7&resolution=0.001',
#    'error': 0.0272159627,
#    'ppm': 272.0856,
#    'info': 'ClON3H7(+1)'},
#   {'em': 99.9721866344,
#    'mf': 'CH2ClFO2(+1)',
#    'unsat': 0,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFO2CH2&resolution=0.001',
#    'error': -0.0278133656,
#    'ppm': -278.211,
#    'info': 'ClFO2CH2(+1)'},
#   {'em': 100.0278716759,
#    'mf': 'H5FN2O3(+1)',
#    'unsat': -1,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FO3N2H5&resolution=0.001',
#    'error': 0.0278716759,
#    'ppm': 278.6391,
#    'info': 'FO3N2H5(+1)'},
#   {'em': 99.9715309212,
#    'mf': 'CH4Cl2N(+1)',
#    'unsat': -0.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2NCH4&resolution=0.001',
#    'error': -0.0284690788,
#    'ppm': -284.7719,
#    'info': 'Cl2NCH4(+1)'},
#   {'em': 100.0285586319,
#    'mf': 'C2H9ClO2(+1)',
#    'unsat': -2,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClO2C2H9&resolution=0.001',
#    'error': 0.0285586319,
#    'ppm': 285.5048,
#    'info': 'ClO2C2H9(+1)'},
#   {'em': 99.9710437557,
#    'mf': 'C4HClO(+1)',
#    'unsat': 4,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClOC4H&resolution=0.001',
#    'error': -0.0289562443,
#    'ppm': -289.6463,
#    'info': 'ClOC4H(+1)'},
#   {'em': 100.0305517579,
#    'mf': 'C3H3FN3(+1)',
#    'unsat': 3.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FN3C3H3&resolution=0.001',
#    'error': 0.0305517579,
#    'ppm': 305.4243,
#    'info': 'FN3C3H3(+1)'},
#   {'em': 100.0307515484,
#    'mf': 'C8H4(+1)',
#    'unsat': 7,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/C8H4&resolution=0.001',
#    'error': 0.0307515484,
#    'ppm': 307.4209,
#    'info': 'C8H4(+1)'},
#   {'em': 100.0316946365,
#    'mf': 'H4F2N3O(+1)',
#    'unsat': -0.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2ON3H4&resolution=0.001',
#    'error': 0.0316946365,
#    'ppm': 316.8459,
#    'info': 'F2ON3H4(+1)'},
#   {'em': 100.031894427,
#    'mf': 'C5H5FO(+1)',
#    'unsat': 3,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FOC5H5&resolution=0.001',
#    'error': 0.031894427,
#    'ppm': 318.8426,
#    'info': 'FOC5H5(+1)'},
#   {'em': 100.0323815925,
#    'mf': 'C2H8ClFN(+1)',
#    'unsat': -1.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFNC2H8&resolution=0.001',
#    'error': 0.0323815925,
#    'ppm': 323.7111,
#    'info': 'ClFNC2H8(+1)'},
#   {'em': 100.0330373056,
#    'mf': 'C2H6F2O2(+1)',
#    'unsat': -1,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2O2C2H6&resolution=0.001',
#    'error': 0.0330373056,
#    'ppm': 330.2639,
#    'info': 'F2O2C2H6(+1)'},
#   {'em': 100.0366195183,
#    'mf': 'H2N7(+1)',
#    'unsat': 3.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N7H2&resolution=0.001',
#    'error': 0.0366195183,
#    'ppm': 366.0611,
#    'info': 'N7H2(+1)'},
#   {'em': 100.0366247745,
#    'mf': 'CH8O5(+1)',
#    'unsat': -2,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O5CH8&resolution=0.001',
#    'error': 0.0366247745,
#    'ppm': 366.1137,
#    'info': 'O5CH8(+1)'},
#   {'em': 100.0368602663,
#    'mf': 'C2H5F3N(+1)',
#    'unsat': -0.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F3NC2H5&resolution=0.001',
#    'error': 0.0368602663,
#    'ppm': 368.46680000000003,
#    'info': 'F3NC2H5(+1)'},
#   {'em': 100.0379621874,
#    'mf': 'C2H4N4O(+1)',
#    'unsat': 3,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ON4C2H4&resolution=0.001',
#    'error': 0.0379621874,
#    'ppm': 379.4778,
#    'info': 'ON4C2H4(+1)'},
#   {'em': 100.0393048565,
#    'mf': 'C4H6NO2(+1)',
#    'unsat': 2.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O2NC4H6&resolution=0.001',
#    'error': 0.0393048565,
#    'ppm': 392.8941,
#    'info': 'O2NC4H6(+1)'},
#   {'em': 100.039792022,
#    'mf': 'CH9ClN2O(+1)',
#    'unsat': -2,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClON2CH9&resolution=0.001',
#    'error': 0.039792022,
#    'ppm': 397.76189999999997,
#    'info': 'ClON2CH9(+1)'},
#   {'em': 99.9596105751,
#    'mf': 'ClFNO2(+1)',
#    'unsat': 0.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFO2N&resolution=0.001',
#    'error': -0.0403894249,
#    'ppm': -404.05740000000003,
#    'info': 'ClFO2N(+1)'},
#   {'em': 100.0404477351,
#    'mf': 'CH7FNO3(+1)',
#    'unsat': -1.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FO3NCH7&resolution=0.001',
#    'error': 0.0404477351,
#    'ppm': 404.3138,
#    'info': 'FO3NCH7(+1)'},
#   {'em': 99.958954862,
#    'mf': 'H2Cl2N2(+1)',
#    'unsat': 0,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2N2H2&resolution=0.001',
#    'error': -0.041045138,
#    'ppm': -410.61990000000003,
#    'info': 'Cl2N2H2(+1)'},
#   {'em': 100.0416218566,
#    'mf': 'H14Cl2O(+1)',
#    'unsat': -7,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2OH14&resolution=0.001',
#    'error': 0.0416218566,
#    'ppm': 416.04540000000003,
#    'info': 'Cl2OH14(+1)'},
#   {'em': 100.0431278172,
#    'mf': 'C4H5FN2(+1)',
#    'unsat': 3,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FN2C4H5&resolution=0.001',
#    'error': 0.0431278172,
#    'ppm': 431.09229999999997,
#    'info': 'FN2C4H5(+1)'},
#   {'em': 99.9557876144,
#    'mf': 'HClO4(+1)',
#    'unsat': 0,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClO4H&resolution=0.001',
#    'error': -0.0442123856,
#    'ppm': -442.31940000000003,
#    'info': 'ClO4H(+1)'},
#   {'em': 100.0442706958,
#    'mf': 'CH6F2N2O(+1)',
#    'unsat': -1,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2ON2CH6&resolution=0.001',
#    'error': 0.0442706958,
#    'ppm': 442.5111,
#    'info': 'F2ON2CH6(+1)'},
#   {'em': 100.0449576518,
#    'mf': 'C3H10ClF(+1)',
#    'unsat': -2,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFC3H10&resolution=0.001',
#    'error': 0.0449576518,
#    'ppm': 449.3745,
#    'info': 'ClFC3H10(+1)'},
#   {'em': 100.0461005304,
#    'mf': 'H11ClF2O(+1)',
#    'unsat': -6,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF2OH11&resolution=0.001',
#    'error': 0.0461005304,
#    'ppm': 460.7929,
#    'info': 'ClF2OH11(+1)'},
#   {'em': 100.0478581646,
#    'mf': 'H8N2O4(+1)',
#    'unsat': -2,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O4N2H8&resolution=0.001',
#    'error': 0.0478581646,
#    'ppm': 478.35269999999997,
#    'info': 'O4N2H8(+1)'},
#   {'em': 99.951828322,
#    'mf': 'H5BrO(+1)',
#    'unsat': -2,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrOH5&resolution=0.001',
#    'error': -0.048171678,
#    'ppm': -481.9489,
#    'info': 'BrOH5(+1)'},
#   {'em': 100.0491955775,
#    'mf': 'CH4N6(+1)',
#    'unsat': 3,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N6CH4&resolution=0.001',
#    'error': 0.0491955775,
#    'ppm': 491.7139,
#    'info': 'N6CH4(+1)'},
#   {'em': 100.0494363256,
#    'mf': 'C3H7F3(+1)',
#    'unsat': -1,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F3C3H7&resolution=0.001',
#    'error': 0.0494363256,
#    'ppm': 494.119,
#    'info': 'F3C3H7(+1)'},
#   {'em': 100.0505382467,
#    'mf': 'C3H6N3O(+1)',
#    'unsat': 2.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ON3C3H6&resolution=0.001',
#    'error': 0.0505382467,
#    'ppm': 505.1272,
#    'info': 'ON3C3H6(+1)'},
#   {'em': 100.0510254122,
#    'mf': 'H9ClN4(+1)',
#    'unsat': -2,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClN4H9&resolution=0.001',
#    'error': 0.0510254122,
#    'ppm': 509.9939,
#    'info': 'ClN4H9(+1)'},
#   {'em': 100.0516811253,
#    'mf': 'H7FN3O2(+1)',
#    'unsat': -1.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FO2N3H7&resolution=0.001',
#    'error': 0.0516811253,
#    'ppm': 516.5442999999999,
#    'info': 'FO2N3H7(+1)'},
#   {'em': 100.0518809158,
#    'mf': 'C5H8O2(+1)',
#    'unsat': 2,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O2C5H8&resolution=0.001',
#    'error': 0.0518809158,
#    'ppm': 518.5400999999999,
#    'info': 'O2C5H8(+1)'},
#   {'em': 99.9477214718,
#    'mf': 'CH2Cl2O(+1)',
#    'unsat': 0,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2OCH2&resolution=0.001',
#    'error': -0.0522785282,
#    'ppm': -523.0586999999999,
#    'info': 'Cl2OCH2(+1)'},
#   {'em': 100.0523680813,
#    'mf': 'C2H11ClNO(+1)',
#    'unsat': -2.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClONC2H11&resolution=0.001',
#    'error': 0.0523680813,
#    'ppm': 523.4067,
#    'info': 'ClONC2H11(+1)'},
#   {'em': 100.0530237944,
#    'mf': 'C2H9FO3(+1)',
#    'unsat': -2,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FO3C2H9&resolution=0.001',
#    'error': 0.0530237944,
#    'ppm': 529.9569,
#    'info': 'FO3C2H9(+1)'},
#   {'em': 100.055504086,
#    'mf': 'H6F2N4(+1)',
#    'unsat': -1,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2N4H6&resolution=0.001',
#    'error': 0.055504086,
#    'ppm': 554.733,
#    'info': 'F2N4H6(+1)'},
#   {'em': 100.0557038764,
#    'mf': 'C5H7FN(+1)',
#    'unsat': 2.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FNC5H7&resolution=0.001',
#    'error': 0.0557038764,
#    'ppm': 556.7286,
#    'info': 'FNC5H7(+1)'},
#   {'em': 100.0568467551,
#    'mf': 'C2H8F2NO(+1)',
#    'unsat': -1.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2ONC2H8&resolution=0.001',
#    'error': 0.0568467551,
#    'ppm': 568.1446,
#    'info': 'F2ONC2H8(+1)'},
#   {'em': 100.0604342239,
#    'mf': 'CH10NO4(+1)',
#    'unsat': -2.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O4NCH10&resolution=0.001',
#    'error': 0.0604342239,
#    'ppm': 603.9771999999999,
#    'info': 'O4NCH10(+1)'},
#   {'em': 100.0617716368,
#    'mf': 'C2H6N5(+1)',
#    'unsat': 2.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N5C2H6&resolution=0.001',
#    'error': 0.0617716368,
#    'ppm': 617.335,
#    'info': 'N5C2H6(+1)'},
#   {'em': 100.0631143059,
#    'mf': 'C4H8N2O(+1)',
#    'unsat': 2,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ON2C4H8&resolution=0.001',
#    'error': 0.0631143059,
#    'ppm': 630.745,
#    'info': 'ON2C4H8(+1)'},
#   {'em': 100.0636014715,
#    'mf': 'CH11ClN3(+1)',
#    'unsat': -2.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClN3CH11&resolution=0.001',
#    'error': 0.0636014715,
#    'ppm': 635.6105,
#    'info': 'ClN3CH11(+1)'},
#   {'em': 100.0642571846,
#    'mf': 'CH9FN2O2(+1)',
#    'unsat': -2,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FO2N2CH9&resolution=0.001',
#    'error': 0.0642571846,
#    'ppm': 642.1591999999999,
#    'info': 'FO2N2CH9(+1)'},
#   {'em': 99.9351454125,
#    'mf': 'Cl2NO(+1)',
#    'unsat': 0.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2ON&resolution=0.001',
#    'error': -0.0648545875,
#    'ppm': -648.9668,
#    'info': 'Cl2ON(+1)'},
#   {'em': 100.0649441406,
#    'mf': 'C3H13ClO(+1)',
#    'unsat': -3,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClOC3H13&resolution=0.001',
#    'error': 0.0649441406,
#    'ppm': 649.0199,
#    'info': 'ClOC3H13(+1)'},
#   {'em': 100.0654313061,
#    'mf': 'H16Cl2N(+1)',
#    'unsat': -7.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2NH16&resolution=0.001',
#    'error': 0.0654313061,
#    'ppm': 653.8851999999999,
#    'info': 'Cl2NH16(+1)'},
#   {'em': 100.0660870192,
#    'mf': 'H14ClFO2(+1)',
#    'unsat': -7,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFO2H14&resolution=0.001',
#    'error': 0.0660870192,
#    'ppm': 660.4337,
#    'info': 'ClFO2H14(+1)'},
#   {'em': 100.0680801452,
#    'mf': 'CH8F2N3(+1)',
#    'unsat': -1.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2N3CH8&resolution=0.001',
#    'error': 0.0680801452,
#    'ppm': 680.3383,
#    'info': 'F2N3CH8(+1)'},
#   {'em': 99.9318418332,
#    'mf': 'H2BrF(+1)',
#    'unsat': -1,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrFH2&resolution=0.001',
#    'error': -0.0681581668,
#    'ppm': -682.0465,
#    'info': 'BrFH2(+1)'},
#   {'em': 100.0682799357,
#    'mf': 'C6H9F(+1)',
#    'unsat': 2,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FC6H9&resolution=0.001',
#    'error': 0.0682799357,
#    'ppm': 682.3335,
#    'info': 'FC6H9(+1)'},
#   {'em': 100.0694228144,
#    'mf': 'C3H10F2O(+1)',
#    'unsat': -2,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2OC3H10&resolution=0.001',
#    'error': 0.0694228144,
#    'ppm': 693.7465000000001,
#    'info': 'F2OC3H10(+1)'},
#   {'em': 100.0699099799,
#    'mf': 'H13ClF2N(+1)',
#    'unsat': -6.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF2NH13&resolution=0.001',
#    'error': 0.0699099799,
#    'ppm': 698.6114,
#    'info': 'ClF2NH13(+1)'},
#   {'em': 100.070565693,
#    'mf': 'H11F3O2(+1)',
#    'unsat': -6,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F3O2H11&resolution=0.001',
#    'error': 0.070565693,
#    'ppm': 705.1593,
#    'info': 'F3O2H11(+1)'},
#   {'em': 100.0716676141,
#    'mf': 'H10N3O3(+1)',
#    'unsat': -2.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O3N3H10&resolution=0.001',
#    'error': 0.0716676141,
#    'ppm': 716.1629,
#    'info': 'O3N3H10(+1)'},
#   {'em': 100.0730102832,
#    'mf': 'C2H12O4(+1)',
#    'unsat': -3,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O4C2H12&resolution=0.001',
#    'error': 0.0730102832,
#    'ppm': 729.5702,
#    'info': 'O4C2H12(+1)'},
#   {'em': 100.0743476961,
#    'mf': 'C3H8N4(+1)',
#    'unsat': 2,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N4C3H8&resolution=0.001',
#    'error': 0.0743476961,
#    'ppm': 742.9246,
#    'info': 'N4C3H8(+1)'},
#   {'em': 100.0754905747,
#    'mf': 'H9FN4O(+1)',
#    'unsat': -2,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FON4H9&resolution=0.001',
#    'error': 0.0754905747,
#    'ppm': 754.3362999999999,
#    'info': 'FON4H9(+1)'},
#   {'em': 100.0756903652,
#    'mf': 'C5H10NO(+1)',
#    'unsat': 1.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ONC5H10&resolution=0.001',
#    'error': 0.0756903652,
#    'ppm': 756.3312,
#    'info': 'ONC5H10(+1)'},
#   {'em': 100.0761775307,
#    'mf': 'C2H13ClN2(+1)',
#    'unsat': -3,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClN2C2H13&resolution=0.001',
#    'error': 0.0761775307,
#    'ppm': 761.1954000000001,
#    'info': 'ClN2C2H13(+1)'},
#   {'em': 100.0768332439,
#    'mf': 'C2H11FNO2(+1)',
#    'unsat': -2.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FO2NC2H11&resolution=0.001',
#    'error': 0.0768332439,
#    'ppm': 767.7425999999999,
#    'info': 'FO2NC2H11(+1)'},
#   {'em': 100.0780073654,
#    'mf': 'CH18Cl2(+1)',
#    'unsat': -8,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2CH18&resolution=0.001',
#    'error': 0.0780073654,
#    'ppm': 779.4656,
#    'info': 'Cl2CH18(+1)'},
#   {'em': 100.0806562045,
#    'mf': 'C2H10F2N2(+1)',
#    'unsat': -2,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2N2C2H10&resolution=0.001',
#    'error': 0.0806562045,
#    'ppm': 805.912,
#    'info': 'F2N2C2H10(+1)'},
#   {'em': 100.0821142156,
#    'mf': 'H21Br(+1)',
#    'unsat': -10,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/BrH21&resolution=0.001',
#    'error': 0.0821142156,
#    'ppm': 820.4684,
#    'info': 'BrH21(+1)'},
#   {'em': 100.0824860392,
#    'mf': 'CH15ClF2(+1)',
#    'unsat': -7,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF2CH15&resolution=0.001',
#    'error': 0.0824860392,
#    'ppm': 824.1806,
#    'info': 'ClF2CH15(+1)'},
#   {'em': 100.0842436733,
#    'mf': 'CH12N2O3(+1)',
#    'unsat': -3,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O3N2CH12&resolution=0.001',
#    'error': 0.0842436733,
#    'ppm': 841.7276,
#    'info': 'O3N2CH12(+1)'},
#   {'em': 100.086073508,
#    'mf': 'H17ClO3(+1)',
#    'unsat': -8,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClO3H17&resolution=0.001',
#    'error': 0.086073508,
#    'ppm': 859.9949,
#    'info': 'ClO3H17(+1)'},
#   {'em': 100.0869237554,
#    'mf': 'C4H10N3(+1)',
#    'unsat': 1.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N3C4H10&resolution=0.001',
#    'error': 0.0869237554,
#    'ppm': 868.4826,
#    'info': 'N3C4H10(+1)'},
#   {'em': 100.088066634,
#    'mf': 'CH11FN3O(+1)',
#    'unsat': -2.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FON3CH11&resolution=0.001',
#    'error': 0.088066634,
#    'ppm': 879.8914,
#    'info': 'FON3CH11(+1)'},
#   {'em': 100.0882664245,
#    'mf': 'C6H12O(+1)',
#    'unsat': 1,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/OC6H12&resolution=0.001',
#    'error': 0.0882664245,
#    'ppm': 881.8857999999999,
#    'info': 'OC6H12(+1)'},
#   {'em': 100.08875359,
#    'mf': 'C3H15ClN(+1)',
#    'unsat': -3.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClNC3H15&resolution=0.001',
#    'error': 0.08875359,
#    'ppm': 886.7489,
#    'info': 'ClNC3H15(+1)'},
#   {'em': 100.0894093031,
#    'mf': 'C3H13FO2(+1)',
#    'unsat': -3,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FO2C3H13&resolution=0.001',
#    'error': 0.0894093031,
#    'ppm': 893.2943,
#    'info': 'FO2C3H13(+1)'},
#   {'em': 100.0898964686,
#    'mf': 'H16ClFNO(+1)',
#    'unsat': -7.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFONH16&resolution=0.001',
#    'error': 0.0898964686,
#    'ppm': 898.1573,
#    'info': 'ClFONH16(+1)'},
#   {'em': 100.0905521818,
#    'mf': 'H14F2O3(+1)',
#    'unsat': -7,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2O3H14&resolution=0.001',
#    'error': 0.0905521818,
#    'ppm': 904.7026,
#    'info': 'F2O3H14(+1)'},
#   {'em': 100.0932322638,
#    'mf': 'C3H12F2N(+1)',
#    'unsat': -2.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2NC3H12&resolution=0.001',
#    'error': 0.0932322638,
#    'ppm': 931.4542,
#    'info': 'F2NC3H12(+1)'},
#   {'em': 100.0943751424,
#    'mf': 'H13F3NO(+1)',
#    'unsat': -6.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F3ONH13&resolution=0.001',
#    'error': 0.0943751424,
#    'ppm': 942.8616000000001,
#    'info': 'F3ONH13(+1)'},
#   {'em': 100.0954770635,
#    'mf': 'H12N4O2(+1)',
#    'unsat': -3,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O2N4H12&resolution=0.001',
#    'error': 0.0954770635,
#    'ppm': 953.8599,
#    'info': 'O2N4H12(+1)'},
#   {'em': 100.0968197326,
#    'mf': 'C2H14NO3(+1)',
#    'unsat': -3.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O3NC2H14&resolution=0.001',
#    'error': 0.0968197326,
#    'ppm': 967.2608,
#    'info': 'O3NC2H14(+1)'},
#   {'em': 100.0993000242,
#    'mf': 'H11FN5(+1)',
#    'unsat': -2.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FN5H11&resolution=0.001',
#    'error': 0.0993000242,
#    'ppm': 992.0152,
#    'info': 'FN5H11(+1)'},
#   {'em': 100.0994998147,
#    'mf': 'C5H12N2(+1)',
#    'unsat': 1,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N2C5H12&resolution=0.001',
#    'error': 0.0994998147,
#    'ppm': 994.0091,
#    'info': 'N2C5H12(+1)'},
#   {'em': 100.1006426933,
#    'mf': 'C2H13FN2O(+1)',
#    'unsat': -3,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FON2C2H13&resolution=0.001',
#    'error': 0.1006426933,
#    'ppm': 1005.4150999999999,
#    'info': 'FON2C2H13(+1)'},
#   {'em': 100.1013296493,
#    'mf': 'C4H17Cl(+1)',
#    'unsat': -4,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClC4H17&resolution=0.001',
#    'error': 0.1013296493,
#    'ppm': 1012.2708000000001,
#    'info': 'ClC4H17(+1)'},
#   {'em': 100.1024725279,
#    'mf': 'CH18ClFO(+1)',
#    'unsat': -8,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFOCH18&resolution=0.001',
#    'error': 0.1024725279,
#    'ppm': 1023.6763,
#    'info': 'ClFOCH18(+1)'},
#   {'em': 100.1058083231,
#    'mf': 'C4H14F2(+1)',
#    'unsat': -3,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2C4H14&resolution=0.001',
#    'error': 0.1058083231,
#    'ppm': 1056.9649,
#    'info': 'F2C4H14(+1)'},
#   {'em': 100.1069512017,
#    'mf': 'CH15F3O(+1)',
#    'unsat': -7,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F3OCH15&resolution=0.001',
#    'error': 0.1069512017,
#    'ppm': 1068.3693999999998,
#    'info': 'F3OCH15(+1)'},
#   {'em': 100.1080531228,
#    'mf': 'CH14N3O2(+1)',
#    'unsat': -3.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O2N3CH14&resolution=0.001',
#    'error': 0.1080531228,
#    'ppm': 1079.3649,
#    'info': 'O2N3CH14(+1)'},
#   {'em': 100.1093957919,
#    'mf': 'C3H16O3(+1)',
#    'unsat': -4,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O3C3H16&resolution=0.001',
#    'error': 0.1093957919,
#    'ppm': 1092.7624999999998,
#    'info': 'O3C3H16(+1)'},
#   {'em': 100.1098829574,
#    'mf': 'H19ClNO2(+1)',
#    'unsat': -8.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClO2NH19&resolution=0.001',
#    'error': 0.1098829574,
#    'ppm': 1097.6235,
#    'info': 'ClO2NH19(+1)'},
#   {'em': 100.1105386705,
#    'mf': 'H17FO4(+1)',
#    'unsat': -8,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FO4H17&resolution=0.001',
#    'error': 0.1105386705,
#    'ppm': 1104.1662000000001,
#    'info': 'FO4H17(+1)'},
#   {'em': 100.1118760835,
#    'mf': 'CH13FN4(+1)',
#    'unsat': -3,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FN4CH13&resolution=0.001',
#    'error': 0.1118760835,
#    'ppm': 1117.5105999999998,
#    'info': 'FN4CH13(+1)'},
#   {'em': 100.1120758739,
#    'mf': 'C6H14N(+1)',
#    'unsat': 0.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/NC6H14&resolution=0.001',
#    'error': 0.1120758739,
#    'ppm': 1119.504,
#    'info': 'NC6H14(+1)'},
#   {'em': 100.1132187526,
#    'mf': 'C3H15FNO(+1)',
#    'unsat': -3.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FONC3H15&resolution=0.001',
#    'error': 0.1132187526,
#    'ppm': 1130.9071000000001,
#    'info': 'FONC3H15(+1)'},
#   {'em': 100.1137059181,
#    'mf': 'H18ClFN2(+1)',
#    'unsat': -8,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFN2H18&resolution=0.001',
#    'error': 0.1137059181,
#    'ppm': 1135.7677,
#    'info': 'ClFN2H18(+1)'},
#   {'em': 100.1143616312,
#    'mf': 'H16F2NO2(+1)',
#    'unsat': -7.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2O2NH16&resolution=0.001',
#    'error': 0.1143616312,
#    'ppm': 1142.3099,
#    'info': 'F2O2NH16(+1)'},
#   {'em': 100.1181845919,
#    'mf': 'H15F3N2(+1)',
#    'unsat': -7,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F3N2H15&resolution=0.001',
#    'error': 0.1181845919,
#    'ppm': 1180.4508,
#    'info': 'F3N2H15(+1)'},
#   {'em': 100.1192865129,
#    'mf': 'H14N5O(+1)',
#    'unsat': -3.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ON5H14&resolution=0.001',
#    'error': 0.1192865129,
#    'ppm': 1191.4439,
#    'info': 'ON5H14(+1)'},
#   {'em': 100.1206291821,
#    'mf': 'C2H16N2O2(+1)',
#    'unsat': -4,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O2N2C2H16&resolution=0.001',
#    'error': 0.1206291821,
#    'ppm': 1204.8384,
#    'info': 'O2N2C2H16(+1)'},
#   {'em': 100.1224590167,
#    'mf': 'CH21ClO2(+1)',
#    'unsat': -9,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClO2CH21&resolution=0.001',
#    'error': 0.1224590167,
#    'ppm': 1223.0924,
#    'info': 'ClO2CH21(+1)'},
#   {'em': 100.1244521427,
#    'mf': 'C2H15FN3(+1)',
#    'unsat': -3.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FN3C2H15&resolution=0.001',
#    'error': 0.1244521427,
#    'ppm': 1242.9745,
#    'info': 'FN3C2H15(+1)'},
#   {'em': 100.1246519332,
#    'mf': 'C7H16(+1)',
#    'unsat': 0,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/C7H16&resolution=0.001',
#    'error': 0.1246519332,
#    'ppm': 1244.9675,
#    'info': 'C7H16(+1)'},
#   {'em': 100.1257948119,
#    'mf': 'C4H17FO(+1)',
#    'unsat': -4,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FOC4H17&resolution=0.001',
#    'error': 0.1257948119,
#    'ppm': 1256.3677,
#    'info': 'FOC4H17(+1)'},
#   {'em': 100.1262819774,
#    'mf': 'CH20ClFN(+1)',
#    'unsat': -8.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFNCH20&resolution=0.001',
#    'error': 0.1262819774,
#    'ppm': 1261.2271,
#    'info': 'ClFNCH20(+1)'},
#   {'em': 100.1269376905,
#    'mf': 'CH18F2O2(+1)',
#    'unsat': -8,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2O2CH18&resolution=0.001',
#    'error': 0.1269376905,
#    'ppm': 1267.7676,
#    'info': 'F2O2CH18(+1)'},
#   {'em': 100.1305251593,
#    'mf': 'H20O5(+1)',
#    'unsat': -9,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O5H20&resolution=0.001',
#    'error': 0.1305251593,
#    'ppm': 1303.5501,
#    'info': 'O5H20(+1)'},
#   {'em': 100.1307606512,
#    'mf': 'CH17F3N(+1)',
#    'unsat': -7.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F3NCH17&resolution=0.001',
#    'error': 0.1307606512,
#    'ppm': 1305.8989000000001,
#    'info': 'F3NCH17(+1)'},
#   {'em': 100.1318625722,
#    'mf': 'CH16N4O(+1)',
#    'unsat': -4,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ON4CH16&resolution=0.001',
#    'error': 0.1318625722,
#    'ppm': 1316.8892,
#    'info': 'ON4CH16(+1)'},
#   {'em': 100.1332052414,
#    'mf': 'C3H18NO2(+1)',
#    'unsat': -4.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O2NC3H18&resolution=0.001',
#    'error': 0.1332052414,
#    'ppm': 1330.2804,
#    'info': 'O2NC3H18(+1)'},
#   {'em': 100.1336924069,
#    'mf': 'H21ClN2O(+1)',
#    'unsat': -9,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClON2H21&resolution=0.001',
#    'error': 0.1336924069,
#    'ppm': 1335.1390999999999,
#    'info': 'ClON2H21(+1)'},
#   {'em': 100.13434812,
#    'mf': 'H19FNO3(+1)',
#    'unsat': -8.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FO3NH19&resolution=0.001',
#    'error': 0.13434812,
#    'ppm': 1341.6787,
#    'info': 'FO3NH19(+1)'},
#   {'em': 100.137028202,
#    'mf': 'C3H17FN2(+1)',
#    'unsat': -4,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FN2C3H17&resolution=0.001',
#    'error': 0.137028202,
#    'ppm': 1368.4069,
#    'info': 'FN2C3H17(+1)'},
#   {'em': 100.1381710807,
#    'mf': 'H18F2N2O(+1)',
#    'unsat': -8,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2ON2H18&resolution=0.001',
#    'error': 0.1381710807,
#    'ppm': 1379.8043,
#    'info': 'F2ON2H18(+1)'},
#   {'em': 100.1388580367,
#    'mf': 'C2H22ClF(+1)',
#    'unsat': -9,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFC2H22&resolution=0.001',
#    'error': 0.1388580367,
#    'ppm': 1386.6549,
#    'info': 'ClFC2H22(+1)'},
#   {'em': 100.1430959624,
#    'mf': 'H16N6(+1)',
#    'unsat': -4,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N6H16&resolution=0.001',
#    'error': 0.1430959624,
#    'ppm': 1428.9149,
#    'info': 'N6H16(+1)'},
#   {'em': 100.1433367104,
#    'mf': 'C2H19F3(+1)',
#    'unsat': -8,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F3C2H19&resolution=0.001',
#    'error': 0.1433367104,
#    'ppm': 1431.3155,
#    'info': 'F3C2H19(+1)'},
#   {'em': 100.1444386315,
#    'mf': 'C2H18N3O(+1)',
#    'unsat': -4.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ON3C2H18&resolution=0.001',
#    'error': 0.1444386315,
#    'ppm': 1442.3031,
#    'info': 'ON3C2H18(+1)'},
#   {'em': 100.1457813006,
#    'mf': 'C4H20O2(+1)',
#    'unsat': -5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O2C4H20&resolution=0.001',
#    'error': 0.1457813006,
#    'ppm': 1455.6909,
#    'info': 'O2C4H20(+1)'},
#   {'em': 100.1462684661,
#    'mf': 'CH23ClNO(+1)',
#    'unsat': -9.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClONCH23&resolution=0.001',
#    'error': 0.1462684661,
#    'ppm': 1460.5483,
#    'info': 'ClONCH23(+1)'},
#   {'em': 100.1469241793,
#    'mf': 'CH21FO3(+1)',
#    'unsat': -9,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FO3CH21&resolution=0.001',
#    'error': 0.1469241793,
#    'ppm': 1467.0863,
#    'info': 'FO3CH21(+1)'},
#   {'em': 100.1496042613,
#    'mf': 'C4H19FN(+1)',
#    'unsat': -4.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FNC4H19&resolution=0.001',
#    'error': 0.1496042613,
#    'ppm': 1493.8078,
#    'info': 'FNC4H19(+1)'},
#   {'em': 100.1507471399,
#    'mf': 'CH20F2NO(+1)',
#    'unsat': -8.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2ONCH20&resolution=0.001',
#    'error': 0.1507471399,
#    'ppm': 1505.2023000000002,
#    'info': 'F2ONCH20(+1)'},
#   {'em': 100.1543346088,
#    'mf': 'H22NO4(+1)',
#    'unsat': -9.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O4NH22&resolution=0.001',
#    'error': 0.1543346088,
#    'ppm': 1540.9678,
#    'info': 'O4NH22(+1)'},
#   {'em': 100.1556720217,
#    'mf': 'CH18N5(+1)',
#    'unsat': -4.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N5CH18&resolution=0.001',
#    'error': 0.1556720217,
#    'ppm': 1554.3006,
#    'info': 'N5CH18(+1)'},
#   {'em': 100.1570146908,
#    'mf': 'C3H20N2O(+1)',
#    'unsat': -5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ON2C3H20&resolution=0.001',
#    'error': 0.1570146908,
#    'ppm': 1567.6854,
#    'info': 'ON2C3H20(+1)'},
#   {'em': 100.1575018563,
#    'mf': 'H23ClN3(+1)',
#    'unsat': -9.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClN3H23&resolution=0.001',
#    'error': 0.1575018563,
#    'ppm': 1572.5418,
#    'info': 'ClN3H23(+1)'},
#   {'em': 100.1581575694,
#    'mf': 'H21FN2O2(+1)',
#    'unsat': -9,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FO2N2H21&resolution=0.001',
#    'error': 0.1581575694,
#    'ppm': 1579.0783,
#    'info': 'FO2N2H21(+1)'},
#   {'em': 100.1588445254,
#    'mf': 'C2H25ClO(+1)',
#    'unsat': -10,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClOC2H25&resolution=0.001',
#    'error': 0.1588445254,
#    'ppm': 1585.9261,
#    'info': 'ClOC2H25(+1)'},
#   {'em': 100.1619805301,
#    'mf': 'H20F2N3(+1)',
#    'unsat': -8.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2N3H20&resolution=0.001',
#    'error': 0.1619805301,
#    'ppm': 1617.1858,
#    'info': 'F2N3H20(+1)'},
#   {'em': 100.1621803206,
#    'mf': 'C5H21F(+1)',
#    'unsat': -5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FC5H21&resolution=0.001',
#    'error': 0.1621803206,
#    'ppm': 1619.1771999999999,
#    'info': 'FC5H21(+1)'},
#   {'em': 100.1633231992,
#    'mf': 'C2H22F2O(+1)',
#    'unsat': -9,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2OC2H22&resolution=0.001',
#    'error': 0.1633231992,
#    'ppm': 1630.5689,
#    'info': 'F2OC2H22(+1)'},
#   {'em': 100.166910668,
#    'mf': 'CH24O4(+1)',
#    'unsat': -10,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O4CH24&resolution=0.001',
#    'error': 0.166910668,
#    'ppm': 1666.3254000000002,
#    'info': 'O4CH24(+1)'},
#   {'em': 100.168248081,
#    'mf': 'C2H20N4(+1)',
#    'unsat': -5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N4C2H20&resolution=0.001',
#    'error': 0.168248081,
#    'ppm': 1679.6548,
#    'info': 'N4C2H20(+1)'},
#   {'em': 100.1695907501,
#    'mf': 'C4H22NO(+1)',
#    'unsat': -5.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ONC4H22&resolution=0.001',
#    'error': 0.1695907501,
#    'ppm': 1693.0363,
#    'info': 'ONC4H22(+1)'},
#   {'em': 100.1700779156,
#    'mf': 'CH25ClN2(+1)',
#    'unsat': -10,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClN2CH25&resolution=0.001',
#    'error': 0.1700779156,
#    'ppm': 1697.8914,
#    'info': 'ClN2CH25(+1)'},
#   {'em': 100.1707336287,
#    'mf': 'CH23FNO2(+1)',
#    'unsat': -9.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FO2NCH23&resolution=0.001',
#    'error': 0.1707336287,
#    'ppm': 1704.4263,
#    'info': 'FO2NCH23(+1)'},
#   {'em': 100.1719077502,
#    'mf': 'H30Cl2(+1)',
#    'unsat': -15,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/Cl2H30&resolution=0.001',
#    'error': 0.1719077502,
#    'ppm': 1716.1272999999999,
#    'info': 'Cl2H30(+1)'},
#   {'em': 100.1745565894,
#    'mf': 'CH22F2N2(+1)',
#    'unsat': -9,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2N2CH22&resolution=0.001',
#    'error': 0.1745565894,
#    'ppm': 1742.5241999999998,
#    'info': 'F2N2CH22(+1)'},
#   {'em': 100.176386424,
#    'mf': 'H27ClF2(+1)',
#    'unsat': -14,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClF2H27&resolution=0.001',
#    'error': 0.176386424,
#    'ppm': 1760.7585,
#    'info': 'ClF2H27(+1)'},
#   {'em': 100.1781440582,
#    'mf': 'H24N2O3(+1)',
#    'unsat': -10,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O3N2H24&resolution=0.001',
#    'error': 0.1781440582,
#    'ppm': 1778.2727,
#    'info': 'O3N2H24(+1)'},
#   {'em': 100.1808241402,
#    'mf': 'C3H22N3(+1)',
#    'unsat': -5.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N3C3H22&resolution=0.001',
#    'error': 0.1808241402,
#    'ppm': 1804.9776,
#    'info': 'N3C3H22(+1)'},
#   {'em': 100.1819670189,
#    'mf': 'H23FN3O(+1)',
#    'unsat': -9.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FON3H23&resolution=0.001',
#    'error': 0.1819670189,
#    'ppm': 1816.365,
#    'info': 'FON3H23(+1)'},
#   {'em': 100.1821668094,
#    'mf': 'C5H24O(+1)',
#    'unsat': -6,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/OC5H24&resolution=0.001',
#    'error': 0.1821668094,
#    'ppm': 1818.3557,
#    'info': 'OC5H24(+1)'},
#   {'em': 100.1826539749,
#    'mf': 'C2H27ClN(+1)',
#    'unsat': -10.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClNC2H27&resolution=0.001',
#    'error': 0.1826539749,
#    'ppm': 1823.2096000000001,
#    'info': 'ClNC2H27(+1)'},
#   {'em': 100.183309688,
#    'mf': 'C2H25FO2(+1)',
#    'unsat': -10,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FO2C2H25&resolution=0.001',
#    'error': 0.183309688,
#    'ppm': 1829.7428,
#    'info': 'FO2C2H25(+1)'},
#   {'em': 100.1871326487,
#    'mf': 'C2H24F2N(+1)',
#    'unsat': -9.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2NC2H24&resolution=0.001',
#    'error': 0.1871326487,
#    'ppm': 1867.8312,
#    'info': 'F2NC2H24(+1)'},
#   {'em': 100.1907201175,
#    'mf': 'CH26NO3(+1)',
#    'unsat': -10.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O3NCH26&resolution=0.001',
#    'error': 0.1907201175,
#    'ppm': 1903.5707,
#    'info': 'O3NCH26(+1)'},
#   {'em': 100.1934001995,
#    'mf': 'C4H24N2(+1)',
#    'unsat': -6,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N2C4H24&resolution=0.001',
#    'error': 0.1934001995,
#    'ppm': 1930.2689,
#    'info': 'N2C4H24(+1)'},
#   {'em': 100.1945430781,
#    'mf': 'CH25FN2O(+1)',
#    'unsat': -10,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FON2CH25&resolution=0.001',
#    'error': 0.1945430781,
#    'ppm': 1941.6534,
#    'info': 'FON2CH25(+1)'},
#   {'em': 100.1952300341,
#    'mf': 'C3H29Cl(+1)',
#    'unsat': -11,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClC3H29&resolution=0.001',
#    'error': 0.1952300341,
#    'ppm': 1948.4963,
#    'info': 'ClC3H29(+1)'},
#   {'em': 100.1963729128,
#    'mf': 'H30ClFO(+1)',
#    'unsat': -15,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFOH30&resolution=0.001',
#    'error': 0.1963729128,
#    'ppm': 1959.8805,
#    'info': 'ClFOH30(+1)'},
#   {'em': 100.1997087079,
#    'mf': 'C3H26F2(+1)',
#    'unsat': -10,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2C3H26&resolution=0.001',
#    'error': 0.1997087079,
#    'ppm': 1993.1067,
#    'info': 'F2C3H26(+1)'},
#   {'em': 100.2008515866,
#    'mf': 'H27F3O(+1)',
#    'unsat': -14,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F3OH27&resolution=0.001',
#    'error': 0.2008515866,
#    'ppm': 2004.4898000000003,
#    'info': 'F3OH27(+1)'},
#   {'em': 100.2019535076,
#    'mf': 'H26N3O2(+1)',
#    'unsat': -10.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O2N3H26&resolution=0.001',
#    'error': 0.2019535076,
#    'ppm': 2015.4648,
#    'info': 'O2N3H26(+1)'},
#   {'em': 100.2032961768,
#    'mf': 'C2H28O3(+1)',
#    'unsat': -11,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O3C2H28&resolution=0.001',
#    'error': 0.2032961768,
#    'ppm': 2028.8372,
#    'info': 'O3C2H28(+1)'},
#   {'em': 100.2057764683,
#    'mf': 'H25FN4(+1)',
#    'unsat': -10,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FN4H25&resolution=0.001',
#    'error': 0.2057764683,
#    'ppm': 2053.539,
#    'info': 'FN4H25(+1)'},
#   {'em': 100.2059762588,
#    'mf': 'C5H26N(+1)',
#    'unsat': -6.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/NC5H26&resolution=0.001',
#    'error': 0.2059762588,
#    'ppm': 2055.5287,
#    'info': 'NC5H26(+1)'},
#   {'em': 100.2071191374,
#    'mf': 'C2H27FNO(+1)',
#    'unsat': -10.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FONC2H27&resolution=0.001',
#    'error': 0.2071191374,
#    'ppm': 2066.9104,
#    'info': 'FONC2H27(+1)'},
#   {'em': 100.2145295669,
#    'mf': 'CH28N2O2(+1)',
#    'unsat': -11,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O2N2CH28&resolution=0.001',
#    'error': 0.2145295669,
#    'ppm': 2140.7032,
#    'info': 'O2N2CH28(+1)'},
#   {'em': 100.2163594016,
#    'mf': 'H33ClO2(+1)',
#    'unsat': -16,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClO2H33&resolution=0.001',
#    'error': 0.2163594016,
#    'ppm': 2158.9230000000002,
#    'info': 'ClO2H33(+1)'},
#   {'em': 100.2183525276,
#    'mf': 'CH27FN3(+1)',
#    'unsat': -10.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FN3CH27&resolution=0.001',
#    'error': 0.2183525276,
#    'ppm': 2178.7679000000003,
#    'info': 'FN3CH27(+1)'},
#   {'em': 100.2185523181,
#    'mf': 'C6H28(+1)',
#    'unsat': -7,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/C6H28&resolution=0.001',
#    'error': 0.2185523181,
#    'ppm': 2180.7571000000003,
#    'info': 'C6H28(+1)'},
#   {'em': 100.2196951967,
#    'mf': 'C3H29FO(+1)',
#    'unsat': -11,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FOC3H29&resolution=0.001',
#    'error': 0.2196951967,
#    'ppm': 2192.1358999999998,
#    'info': 'FOC3H29(+1)'},
#   {'em': 100.2201823622,
#    'mf': 'H32ClFN(+1)',
#    'unsat': -15.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFNH32&resolution=0.001',
#    'error': 0.2201823622,
#    'ppm': 2196.9862,
#    'info': 'ClFNH32(+1)'},
# ...
#    'ppm': 2614.6304,
#    'info': 'N4CH32(+1)'},
#   {'em': 100.2634911349,
#    'mf': 'C3H34NO(+1)',
#    'unsat': -12.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ONC3H34&resolution=0.001',
#    'error': 0.2634911349,
#    'ppm': 2627.9868,
#    'info': 'ONC3H34(+1)'},
#   {'em': 100.2639783004,
#    'mf': 'H37ClN2(+1)',
#    'unsat': -17,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClN2H37&resolution=0.001',
#    'error': 0.2639783004,
#    'ppm': 2632.8329000000003,
#    'info': 'ClN2H37(+1)'},
#   {'em': 100.2646340136,
#    'mf': 'H35FNO2(+1)',
#    'unsat': -16.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FO2NH35&resolution=0.001',
#    'error': 0.2646340136,
#    'ppm': 2639.3555,
#    'info': 'FO2NH35(+1)'},
#   {'em': 100.2684569742,
#    'mf': 'H34F2N2(+1)',
#    'unsat': -16,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2N2H34&resolution=0.001',
#    'error': 0.2684569742,
#    'ppm': 2677.3821,
#    'info': 'F2N2H34(+1)'},
#   {'em': 100.2747245251,
#    'mf': 'C2H34N3(+1)',
#    'unsat': -12.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N3C2H34&resolution=0.001',
#    'error': 0.2747245251,
#    'ppm': 2739.7186,
#    'info': 'N3C2H34(+1)'},
#   {'em': 100.2760671942,
#    'mf': 'C4H36O(+1)',
#    'unsat': -13,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/OC4H36&resolution=0.001',
#    'error': 0.2760671942,
#    'ppm': 2753.0715999999998,
#    'info': 'OC4H36(+1)'},
#   {'em': 100.2765543597,
#    'mf': 'CH39ClN(+1)',
#    'unsat': -17.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClNCH39&resolution=0.001',
#    'error': 0.2765543597,
#    'ppm': 2757.9165000000003,
#    'info': 'ClNCH39(+1)'},
#   {'em': 100.2772100728,
#    'mf': 'CH37FO2(+1)',
#    'unsat': -17,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FO2CH37&resolution=0.001',
#    'error': 0.2772100728,
#    'ppm': 2764.4374,
#    'info': 'FO2CH37(+1)'},
#   {'em': 100.2810330335,
#    'mf': 'CH36F2N(+1)',
#    'unsat': -16.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2NCH36&resolution=0.001',
#    'error': 0.2810330335,
#    'ppm': 2802.4545,
#    'info': 'F2NCH36(+1)'},
#   {'em': 100.2846205023,
#    'mf': 'H38NO3(+1)',
#    'unsat': -17.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O3NH38&resolution=0.001',
#    'error': 0.2846205023,
#    'ppm': 2838.1270999999997,
#    'info': 'O3NH38(+1)'},
#   {'em': 100.2873005844,
#    'mf': 'C3H36N2(+1)',
#    'unsat': -13,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N2C3H36&resolution=0.001',
#    'error': 0.2873005844,
#    'ppm': 2864.7753000000002,
#    'info': 'N2C3H36(+1)'},
#   {'em': 100.288443463,
#    'mf': 'H37FN2O(+1)',
#    'unsat': -17,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FON2H37&resolution=0.001',
#    'error': 0.288443463,
#    'ppm': 2876.1386,
#    'info': 'FON2H37(+1)'},
#   {'em': 100.289130419,
#    'mf': 'C2H41Cl(+1)',
#    'unsat': -18,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClC2H41&resolution=0.001',
#    'error': 0.289130419,
#    'ppm': 2882.9687,
#    'info': 'ClC2H41(+1)'},
#   {'em': 100.2936090928,
#    'mf': 'C2H38F2(+1)',
#    'unsat': -17,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2C2H38&resolution=0.001',
#    'error': 0.2936090928,
#    'ppm': 2927.4955,
#    'info': 'F2C2H38(+1)'},
#   {'em': 100.2971965616,
#    'mf': 'CH40O3(+1)',
#    'unsat': -18,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O3CH40&resolution=0.001',
#    'error': 0.2971965616,
#    'ppm': 2963.1592,
#    'info': 'O3CH40(+1)'},
#   {'em': 100.2998766436,
#    'mf': 'C4H38N(+1)',
#    'unsat': -13.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/NC4H38&resolution=0.001',
#    'error': 0.2998766436,
#    'ppm': 2989.8007000000002,
#    'info': 'NC4H38(+1)'},
#   {'em': 100.3010195223,
#    'mf': 'CH39FNO(+1)',
#    'unsat': -17.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FONCH39&resolution=0.001',
#    'error': 0.3010195223,
#    'ppm': 3001.1611000000003,
#    'info': 'FONCH39(+1)'},
#   {'em': 100.3084299518,
#    'mf': 'H40N2O2(+1)',
#    'unsat': -18,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O2N2H40&resolution=0.001',
#    'error': 0.3084299518,
#    'ppm': 3074.8159,
#    'info': 'O2N2H40(+1)'},
#   {'em': 100.3122529124,
#    'mf': 'H39FN3(+1)',
#    'unsat': -17.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FN3H39&resolution=0.001',
#    'error': 0.3122529124,
#    'ppm': 3112.8093,
#    'info': 'FN3H39(+1)'},
#   {'em': 100.3124527029,
#    'mf': 'C5H40(+1)',
#    'unsat': -14,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/C5H40&resolution=0.001',
#    'error': 0.3124527029,
#    'ppm': 3114.7948,
#    'info': 'C5H40(+1)'},
#   {'em': 100.3135955816,
#    'mf': 'C2H41FO(+1)',
#    'unsat': -18,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FOC2H41&resolution=0.001',
#    'error': 0.3135955816,
#    'ppm': 3126.1523,
#    'info': 'FOC2H41(+1)'},
#   {'em': 99.6802292103,
#    'mf': 'CH87(+1)',
#    'unsat': -41.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/CH87&resolution=0.001',
#    'error': -0.3197707897,
#    'ppm': -3207.966,
#    'info': 'CH87(+1)'},
#   {'em': 100.3210060111,
#    'mf': 'CH42NO2(+1)',
#    'unsat': -18.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O2NCH42&resolution=0.001',
#    'error': 0.3210060111,
#    'ppm': 3199.7886,
#    'info': 'O2NCH42(+1)'},
#   {'em': 100.3248289717,
#    'mf': 'CH41FN2(+1)',
#    'unsat': -18,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FN2CH41&resolution=0.001',
#    'error': 0.3248289717,
#    'ppm': 3237.7725,
#    'info': 'FN2CH41(+1)'},
#   {'em': 100.3266588064,
#    'mf': 'H46ClF(+1)',
#    'unsat': -23,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClFH46&resolution=0.001',
#    'error': 0.3266588064,
#    'ppm': 3255.9522,
#    'info': 'ClFH46(+1)'},
#   {'em': 100.3311374801,
#    'mf': 'H43F3(+1)',
#    'unsat': -22,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F3H43&resolution=0.001',
#    'error': 0.3311374801,
#    'ppm': 3300.4458000000004,
#    'info': 'F3H43(+1)'},
#   {'em': 100.3322394012,
#    'mf': 'H42N3O(+1)',
#    'unsat': -18.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ON3H42&resolution=0.001',
#    'error': 0.3322394012,
#    'ppm': 3311.3923,
#    'info': 'ON3H42(+1)'},
#   {'em': 99.667653151,
#    'mf': 'H85N(+1)',
#    'unsat': -41,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/NH85&resolution=0.001',
#    'error': -0.332346849,
#    'ppm': -3334.5508,
#    'info': 'NH85(+1)'},
#   {'em': 100.3335820703,
#    'mf': 'C2H44O2(+1)',
#    'unsat': -19,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O2C2H44&resolution=0.001',
#    'error': 0.3335820703,
#    'ppm': 3324.73,
#    'info': 'O2C2H44(+1)'},
#   {'em': 100.337405031,
#    'mf': 'C2H43FN(+1)',
#    'unsat': -18.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FNC2H43&resolution=0.001',
#    'error': 0.337405031,
#    'ppm': 3362.7044,
#    'info': 'FNC2H43(+1)'},
#   {'em': 100.3448154605,
#    'mf': 'CH44N2O(+1)',
#    'unsat': -19,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ON2CH44&resolution=0.001',
#    'error': 0.3448154605,
#    'ppm': 3436.3057,
#    'info': 'ON2CH44(+1)'},
#   {'em': 100.3466452951,
#    'mf': 'H49ClO(+1)',
#    'unsat': -24,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClOH49&resolution=0.001',
#    'error': 0.3466452951,
#    'ppm': 3454.4782,
#    'info': 'ClOH49(+1)'},
#   {'em': 100.3499810903,
#    'mf': 'C3H45F(+1)',
#    'unsat': -19,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FC3H45&resolution=0.001',
#    'error': 0.3499810903,
#    'ppm': 3487.6049,
#    'info': 'FC3H45(+1)'},
#   {'em': 100.3511239689,
#    'mf': 'H46F2O(+1)',
#    'unsat': -23,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2OH46&resolution=0.001',
#    'error': 0.3511239689,
#    'ppm': 3498.9539999999997,
#    'info': 'F2OH46(+1)'},
#   {'em': 100.3560488507,
#    'mf': 'H44N4(+1)',
#    'unsat': -19,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N4H44&resolution=0.001',
#    'error': 0.3560488507,
#    'ppm': 3547.8564,
#    'info': 'N4H44(+1)'},
#   {'em': 99.6438437015,
#    'mf': 'H83O(+1)',
#    'unsat': -40.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/OH83&resolution=0.001',
#    'error': -0.3561562985,
#    'ppm': -3574.2931000000003,
#    'info': 'OH83(+1)'},
#   {'em': 100.3573915198,
#    'mf': 'C2H46NO(+1)',
#    'unsat': -19.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ONC2H46&resolution=0.001',
#    'error': 0.3573915198,
#    'ppm': 3561.1877999999997,
#    'info': 'ONC2H46(+1)'},
#   {'em': 100.3686249099,
#    'mf': 'CH46N3(+1)',
#    'unsat': -19.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N3CH46&resolution=0.001',
#    'error': 0.3686249099,
#    'ppm': 3672.7106,
#    'info': 'N3CH46(+1)'},
#   {'em': 100.3699675791,
#    'mf': 'C3H48O(+1)',
#    'unsat': -20,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/OC3H48&resolution=0.001',
#    'error': 0.3699675791,
#    'ppm': 3686.0386000000003,
#    'info': 'OC3H48(+1)'},
#   {'em': 100.3704547446,
#    'mf': 'H51ClN(+1)',
#    'unsat': -24.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClNH51&resolution=0.001',
#    'error': 0.3704547446,
#    'ppm': 3690.8744,
#    'info': 'ClNH51(+1)'},
#   {'em': 100.3711104577,
#    'mf': 'H49FO2(+1)',
#    'unsat': -24,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FO2H49&resolution=0.001',
#    'error': 0.3711104577,
#    'ppm': 3697.3831999999998,
#    'info': 'FO2H49(+1)'},
#   {'em': 100.3749334184,
#    'mf': 'H48F2N(+1)',
#    'unsat': -23.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2NH48&resolution=0.001',
#    'error': 0.3749334184,
#    'ppm': 3735.3292,
#    'info': 'F2NH48(+1)'},
#   {'em': 99.6238572128,
#    'mf': 'H80F(+1)',
#    'unsat': -39.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FH80&resolution=0.001',
#    'error': -0.3761427872,
#    'ppm': -3775.6296,
#    'info': 'FH80(+1)'},
#   {'em': 100.3812009692,
#    'mf': 'C2H48N2(+1)',
#    'unsat': -20,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N2C2H48&resolution=0.001',
#    'error': 0.3812009692,
#    'ppm': 3797.5335,
#    'info': 'N2C2H48(+1)'},
#   {'em': 100.3830308039,
#    'mf': 'CH53Cl(+1)',
#    'unsat': -25,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClCH53&resolution=0.001',
#    'error': 0.3830308039,
#    'ppm': 3815.6928000000003,
#    'info': 'ClCH53(+1)'},
#   {'em': 100.3875094776,
#    'mf': 'CH50F2(+1)',
#    'unsat': -24,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2CH50&resolution=0.001',
#    'error': 0.3875094776,
#    'ppm': 3860.1364,
#    'info': 'F2CH50(+1)'},
#   {'em': 100.3910969465,
#    'mf': 'H52O3(+1)',
#    'unsat': -25,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O3H52&resolution=0.001',
#    'error': 0.3910969465,
#    'ppm': 3895.7334,
#    'info': 'O3H52(+1)'},
#   {'em': 100.3937770285,
#    'mf': 'C3H50N(+1)',
#    'unsat': -20.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/NC3H50&resolution=0.001',
#    'error': 0.3937770285,
#    'ppm': 3922.3251000000005,
#    'info': 'NC3H50(+1)'},
#   {'em': 100.3949199071,
#    'mf': 'H51FNO(+1)',
#    'unsat': -24.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FONH51&resolution=0.001',
#    'error': 0.3949199071,
#    'ppm': 3933.6642,
#    'info': 'FONH51(+1)'},
#   {'em': 100.4063530878,
#    'mf': 'C4H52(+1)',
#    'unsat': -21,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/C4H52&resolution=0.001',
#    'error': 0.4063530878,
#    'ppm': 4047.0854,
#    'info': 'C4H52(+1)'},
#   {'em': 100.4074959664,
#    'mf': 'CH53FO(+1)',
#    'unsat': -25,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FOCH53&resolution=0.001',
#    'error': 0.4074959664,
#    'ppm': 4058.4217999999996,
#    'info': 'FOCH53(+1)'},
#   {'em': 99.5863288254,
#    'mf': 'C2H75(+1)',
#    'unsat': -34.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/C2H75&resolution=0.001',
#    'error': -0.4136711746,
#    'ppm': -4153.895200000001,
#    'info': 'C2H75(+1)'},
#   {'em': 100.4149063959,
#    'mf': 'H54NO2(+1)',
#    'unsat': -25.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O2NH54&resolution=0.001',
#    'error': 0.4149063959,
#    'ppm': 4131.9204,
#    'info': 'O2NH54(+1)'},
#   {'em': 100.4187293566,
#    'mf': 'H53FN2(+1)',
#    'unsat': -25,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FN2H53&resolution=0.001',
#    'error': 0.4187293566,
#    'ppm': 4169.8333,
#    'info': 'FN2H53(+1)'},
#   {'em': 99.5737527661,
#    'mf': 'CH73N(+1)',
#    'unsat': -34,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/NCH73&resolution=0.001',
#    'error': -0.4262472339,
#    'ppm': -4280.7188,
#    'info': 'NCH73(+1)'},
#   {'em': 100.4274824552,
#    'mf': 'CH56O2(+1)',
#    'unsat': -26,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O2CH56&resolution=0.001',
#    'error': 0.4274824552,
#    'ppm': 4256.6282,
#    'info': 'O2CH56(+1)'},
#   {'em': 100.4313054159,
#    'mf': 'CH55FN(+1)',
#    'unsat': -25.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FNCH55&resolution=0.001',
#    'error': 0.4313054159,
#    'ppm': 4294.5316,
#    'info': 'FNCH55(+1)'},
#   {'em': 100.4387158453,
#    'mf': 'H56N2O(+1)',
#    'unsat': -26,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ON2H56&resolution=0.001',
#    'error': 0.4387158453,
#    'ppm': 4367.9954,
#    'info': 'ON2H56(+1)'},
#   {'em': 99.5611767069,
#    'mf': 'H71N2(+1)',
#    'unsat': -33.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N2H71&resolution=0.001',
#    'error': -0.4388232931,
#    'ppm': -4407.5744,
#    'info': 'N2H71(+1)'},
#   {'em': 100.4438814751,
#    'mf': 'C2H57F(+1)',
#    'unsat': -26,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FC2H57&resolution=0.001',
#    'error': 0.4438814751,
#    'ppm': 4419.1987,
#    'info': 'FC2H57(+1)'},
#   {'em': 99.5499433167,
#    'mf': 'CH71O(+1)',
#    'unsat': -33.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/OCH71&resolution=0.001',
#    'error': -0.4500566833,
#    'ppm': -4520.913500000001,
#    'info': 'OCH71(+1)'},
#   {'em': 100.4512919046,
#    'mf': 'CH58NO(+1)',
#    'unsat': -26.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ONCH58&resolution=0.001',
#    'error': 0.4512919046,
#    'ppm': 4492.6441,
#    'info': 'ONCH58(+1)'},
#   {'em': 100.4625252948,
#    'mf': 'H58N3(+1)',
#    'unsat': -26.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N3H58&resolution=0.001',
#    'error': 0.4625252948,
#    'ppm': 4603.9585,
#    'info': 'N3H58(+1)'},
#   {'em': 99.5373672574,
#    'mf': 'H69NO(+1)',
#    'unsat': -33,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ONH69&resolution=0.001',
#    'error': -0.4626327426,
#    'ppm': -4647.8298,
#    'info': 'ONH69(+1)'},
#   {'em': 100.4638679639,
#    'mf': 'C2H60O(+1)',
#    'unsat': -27,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/OC2H60&resolution=0.001',
#    'error': 0.4638679639,
#    'ppm': 4617.261600000001,
#    'info': 'OC2H60(+1)'},
#   {'em': 99.5299568279,
#    'mf': 'CH68F(+1)',
#    'unsat': -32.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FCH68&resolution=0.001',
#    'error': -0.4700431721,
#    'ppm': -4722.630099999999,
#    'info': 'FCH68(+1)'},
#   {'em': 100.4751013541,
#    'mf': 'CH60N2(+1)',
#    'unsat': -27,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/N2CH60&resolution=0.001',
#    'error': 0.4751013541,
#    'ppm': 4728.5481,
#    'info': 'N2CH60(+1)'},
#   {'em': 100.4769311887,
#    'mf': 'H65Cl(+1)',
#    'unsat': -32,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/ClH65&resolution=0.001',
#    'error': 0.4769311887,
#    'ppm': 4746.6735,
#    'info': 'ClH65(+1)'},
#   {'em': 100.4814098625,
#    'mf': 'H62F2(+1)',
#    'unsat': -31,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/F2H62&resolution=0.001',
#    'error': 0.4814098625,
#    'ppm': 4791.0341,
#    'info': 'F2H62(+1)'},
#   {'em': 99.5173807686,
#    'mf': 'H66FN(+1)',
#    'unsat': -32,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/FNH66&resolution=0.001',
#    'error': -0.4826192314,
#    'ppm': -4849.5974,
#    'info': 'FNH66(+1)'},
#   {'em': 99.513557808,
#    'mf': 'H67O2(+1)',
#    'unsat': -32.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/O2H67&resolution=0.001',
#    'error': -0.486442192,
#    'ppm': -4888.200199999999,
#    'info': 'O2H67(+1)'},
#   {'em': 100.4876774134,
#    'mf': 'C2H62N(+1)',
#    'unsat': -27.5,
#    'jcampURL': 'http://www.chemcalc.org/service/jcamp/NC2H62&resolution=0.001',
#    'error': 0.4876774134,
#    'ppm': 4853.106599999999,
#    'info': 'NC2H62(+1)'}]}

# %% [markdown]
# ## 참고할 만한 package https://pypi.org/project/chem-calc/
